# %% [markdown]
# # Python для анализа данных
#
# *Алла Тамбовцева, НИУ ВШЭ*

# %% [markdown]
# ## Web-scraping
#
# Мы уже немного познакомились со структурой html-файлов, теперь попробуем выгрузить информацию из реальной страницы, а точнее, с реального сайта [nplus1.ru](https://nplus1.ru/).
#
# **Наша задача:** выгрузить недавние новости в датафрейм `pandas`, чтобы потом сохранить все в csv-файл.
#
# Сначала сгрузим весь html-код страницы и сохраним его в отдельную переменную. Для этого нам понадобится библиотека `requests`. Импортируем её:

# %%
import requests

# %% [markdown]
# Сохраним ссылку на главную страницу сайта в переменную `url` для удобства и выгрузим страницу. (Разумеется, это будет работать при подключении к интернету. Если соединение будет отключено, Python выдаст `NewConnectionError`).

# %%
url = 'https://nplus1.ru/' # сохраняем
page = requests.get(url) # загружаем страницу по ссылке

# %% [markdown]
# Если мы просто посмотрим на объект, мы ничего особенного не увидим:

# %%
page  # response 200 - страница загружена
# Out:
# <Response [200]>

# %% [markdown]
# Импортируем функцию `BeautifulSoup` из библиотеки `bs4` (от *beautifulsoup4*) и заберём со страницы `page` код html в виде текста.

# %%
from bs4 import BeautifulSoup  # не спрашивайте, почему BeautifulSoup

# %%
soup = BeautifulSoup(page.text)

# %% [markdown]
# Если выведем `soup` на экран, мы увидим то же самое, что в режиме разработчика или в режиме происмотра исходного кода (`view-source` через *Ctrl+U* в Google Chrome).

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="old-town-road no-js bg-fixed" lang="" style="background-image:url(none)">
# <head>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="black" name="apple-mobile-web-app-status-bar-style"/>
# <meta content="7991d7eb02d759f05b9050e111a7e3eb" name="wmail-verification"/>
# <link href="https://nplus1.ru" rel="canonical"/>
# <link href="/i/favicon-bw.png" rel="icon"/>
# <title>N + 1: научные статьи, новости, открытия</title>
# <!-- for Google -->
# <meta content="N + 1: научные статьи, новости, открытия" name="description"/>
# <meta content="" name="author"/>
# <meta content="" name="copyright"/>
# <!-- for Facebook -->
# <meta content="N + 1: научные статьи, новости, открытия" property="og:title"/>
# <meta content="https://nplus1.ru/i/logo.og.png" property="og:image"/>
# <meta content="https://nplus1.ru" property="og:url"/>
# <meta content="N + 1: научные статьи, новости, открытия" property="og:description"/>
# <!-- for Twitter -->
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@nplusodin" name="twitter:site"/>
# <meta content="N + 1: научные статьи, новости, открытия" name="twitter:title"/>
# <meta content="N + 1: научные статьи, новости, открытия" name="twitter:description"/>
# <meta content="https://nplus1.ru/i/logo.png" name="twitter:image"/>
# <meta content="8c90b02c84ac3b72" name="yandex-verification"/>
# <meta content="b419949322895fc9106e24ed01be58ac" name="pmail-verification"/>
# <link href="https://nplus1.ru/rss" rel="alternate" title="RSS" type="application/rss+xml"/>
# <link href="/css/font-awesome.min.css" rel="stylesheet"/>
# <link href="/css/main.min.css?v=1649061972" rel="stylesheet"/>
# <link href="/css/desktop.min.css?v=1452887696" rel="stylesheet"/>
# <link href="/css/tablet.min.css?v=1499281342" rel="stylesheet"/>
# <link href="/css/mobile.min.css?v=1635965090" rel="stylesheet"/>
# <link href="/js/tests/scopus/css/style.css" rel="stylesheet"/>
# <script src="//ajax.googleapis.com/ajax/libs/jquery/1.11.2/jquery.min.js"></script>
# <script src="//cdnjs.cloudflare.com/ajax/libs/modernizr/2.8.3/modernizr.min.js"></script>
# <script src="/js/lib/adfox.asyn.code.ver3.js" type="text/javascript"> </script>
# <script src="/js/lib/adfox.asyn.code.scroll.js" type="text/javascript"> </script>
# <script crossorigin="anonymous" src="https://yastatic.net/pcode/adfox/loader.js"></script>
# <script async="" src="//s.luxupcdnc.com/t/common_402.js" type="text/javascript"></script>
# <!--  ad -->
# <script type="text/javascript">
# 		    var __colAdLoaded = false;
# 		    var __topAdLoaded = false;
#
# 		    var __id = "";
#
# 		    function detectAd(id){
# 		        var _ad = document.getElementById("AdFox_banner_"+id);
# 		    	    console.debug(_ad);
#
# 		        __id = id;
# 		        if(_ad != null && _ad.innerHTML == ""){
# 		            $(".col-ad").remove();
# 		        }
# 		        __colAdLoaded = true;
# 		    }
# 		    function detectAdTop(id){
# 		        __topAdLoaded = true;
# 		    }
# 		</script>
# <!-- /ad -->
# <script type="application/ld+json"> { "@context": "http://schema.org", "@type": "WebSite", "url": "https://nplus1.ru", "name": "N + 1: научные статьи, новости, открытия", "description": "N + 1: научные статьи, новости, открытия", "image": "https://nplus1.ru/i/logo.png", "publisher": { "@type": "Organization", "name": "N + 1", "logo": { "@type":"ImageObject", "url": "https://nplus1.ru/i/logo-alt.png" }, "sameAs": [ "https://www.facebook.com/nplusone", "https://twitter.com/nplusodin", "https://vk.com/nplusone", "https://ok.ru/nplus1", "https://soundcloud.com/nplus_1", "https://t.me/nplusone" ] }, "potentialAction":{ "@type":"SearchAction", "target":"https://nplus1.ru/search?q={search_term_string}", "query-input":"required name=search_term_string" } } </script>
# </head>
# <body class="_main" style="background-image:url(none)">
# <div class="shadow-overlay"></div>
# <div id="viewport">
# <div id="shadow"></div>
# <div class="ad ad-top">
# <!--AdFox START-->
# <!--yandex_nplus1adv-->
# <!--Площадка: N + 1 / * / *-->
# <!--Тип баннера: Растяжка_100%х250-->
# <!--Расположение: <верх страницы>-->
# <div id="adfox_162739969569252320"></div>
# <script>
#     window.yaContextCb.push(()=>{
#         Ya.adfoxCode.create({
#             ownerId: 386110,
#         containerId: 'adfox_162739969569252320',
#             params: {
#                 pp: 'g',
#             ps: 'fbio',
#             p2: 'hhkj'
#             }
#         })
#     })
# </script>
# </div>
# <header id="header-mobile">
# <div class="container">
# <a class="action-menu pull-left" href="#"><i class="icon icon-navicon"></i></a>
# <a class="link-logo" href="/"><img src="/i/logo-mobile.png"/></a>
# <a class="action-search pull-right" href="#"><i class="icon icon-search"></i></a>
# <form action="/search" class="form-search" method="get">
# <div class="control">
# <input name="q" placeholder="Найти" type="text" value=""/>
# </div>
# <a class="action-search-close" href="#">×</a>
# </form>
# </div>
# <nav class="nav-rubrics">
# <ul>
# <li>
# <a class="" href="/rubric/astronomy">Астрономия</a>
# </li>
# <li>
# <a class="" href="/rubric/physics">Физика</a>
# </li>
# <li>
# <a class="" href="/rubric/biology">Биология</a>
# </li>
# <li>
# <a class="" href="/rubric/robots-drones">Роботы и дроны</a>
# </li>
# <li>
# <a class="" href="/theme/bookshelf">Книжная полка</a>
# </li>
# <li>
# <a class="" href="/theme/Courses">Курсы</a>
# </li>
# <li>
# <a class="" href="/theme/coronavirus-history">Коронавирусные хроники</a>
# </li>
# <li>
# <a class="" href="/theme/offline">N + Offline</a>
# </li>
# </ul>
# </nav>
# </header>
# <div class="js-mediator-container" id="layout">
# <!-- header -->
# <header class="_middle" id="header">
# <div class="row">
# <div class="col col-logo">
# <a class="link-logo" href="/"></a>
# </div>
# <div class="col col-nav-main">
# <form action="/search" class="form-search" method="get">
# <div class="control">
# <input name="q" placeholder="Найти" type="text" value=""/>
# </div>
# <a class="action-search-close" href="#">×</a>
# </form>
# <nav class="nav-rubrics">
# <ul>
# <li>
# <a class="" href="/rubric/astronomy">Астрономия</a>
# </li>
# <li>
# <a class="" href="/rubric/physics">Физика</a>
# </li>
# <li>
# <a class="" href="/rubric/biology">Биология</a>
# </li>
# <li>
# <a class="" href="/rubric/robots-drones">Роботы и дроны</a>
# </li>
# <li>
# <a class="action-search" href="#"><i class="icon icon-search"></i></a>
# </li>
# </ul>
# </nav> <nav class="nav-themes">
# <ul>
# <li data-name="bookshelf">
# <a class="" href="/theme/bookshelf">Книжная полка</a>
# </li>
# <li data-name="Courses">
# <a class="" href="/theme/Courses">Курсы</a>
# </li>
# <li data-name="coronavirus-history">
# <a class="" href="/theme/coronavirus-history">Коронавирусные хроники</a>
# </li>
# <li data-name="offline">
# <a class="" href="/theme/offline">N + Offline</a>
# </li>
# </ul>
# </nav>
# </div>
# </div>
# <div class="container line-up">
# <div class="line line-second">
# <a class="action-line-toggle" href="https://nplus1.ru/blog/2022/06/16/people-and-institutions-of-peters-reform">
# <div class="heading"><span></span></div>
# </a>
# <a class="container-link" href="https://nplus1.ru/blog/2022/06/16/people-and-institutions-of-peters-reform">
# <div class="heading"><span>Книжная полка</span></div>
# <div class="link"><span>Дмитрий Серов «Люди и учреждения Петровской эпохи»</span></div>
# </a>
# <a class="container-link" href="https://nplus1.ru/blog/2022/06/14/eye-of-the-albatross">
# <div class="heading"><span>Книжная полка</span></div>
# <div class="link"><span>Карл Сафина «Глазами альбатроса»</span></div>
# </a>
# <a class="container-link" href="https://nplus1.ru/blog/2022/06/09/le-theoreme-du-parapluie">
# <div class="heading"><span>Книжная полка</span></div>
# <div class="link"><span>Микаэль Лонэ «Теорема зонтика, или Искусство правильно смотреть на мир через призму математики»</span></div>
# </a>
# <a class="container-link" href="https://nplus1.ru/blog/2022/06/07/dig-for-science">
# <div class="heading"><span>Эксперименты</span></div>
# <div class="link"><span>Кладмен — климатолог: как закапывать чайные пакетики, чтобы побыть своего рода ученым</span></div>
# </a>
# <a class="container-link" href="https://nplus1.ru/blog/2022/06/07/breathing-lessons">
# <div class="heading"><span>Книжная полка</span></div>
# <div class="link"><span>Мейлан Хан «Чудо дыхания. Как работают наши легкие и как поддержать их здоровье»</span></div>
# </a>
# <a class="container-link" href="https://nplus1.ru/blog/2022/06/06/marat-spectrometric-analysis">
# <div class="heading"><span>Эксперименты</span></div>
# <div class="link"><span>У меня в глазу спектрометр: инструкция по разложению света невооруженным взглядом</span></div>
# </a>
# <a class="container-link" href="https://nplus1.ru/blog/2022/06/03/tastes-like-moon">
# <div class="heading"><span>Хлеб и вино</span></div>
# <div class="link"><span>На вкус как Луна: зачем NASA кормило тараканов грунтом</span></div>
# </a>
# <a class="container-link" href="https://nplus1.ru/blog/2022/06/03/from-earth-to-neptune-and-beyond">
# <div class="heading"><span>Книжная полка</span></div>
# <div class="link"><span>Игорь Лисов «Разведчики внешних планет»</span></div>
# </a>
# <a class="container-link" href="https://nplus1.ru/blog/2022/05/31/jellyfish-age-backwards">
# <div class="heading"><span>Книжная полка</span></div>
# <div class="link"><span>Никлас Брендборг «Загадка нестареющей медузы»</span></div>
# </a>
# <a class="container-link active" href="https://nplus1.ru/blog/2022/06/20/calling-bullshit">
# <div class="heading"><span>Книжная полка</span></div>
# <div class="link"><span>Карл Бергстром, Джевин Уэст «Полный бред! Скептицизм в мире больших данных»</span></div>
# </a>
# <!-- here -->
# </div>
# </div>
# </header> <!-- /header -->
# <!--  hero -->
# <!-- /hero -->
# <!-- main section -->
# <section id="main">
# <!--   dynamic content -->
# <div class="row" data-adaptive="1" data-middle-class="row-wrap _indent-bottom-no" data-mobile-class="row-wrap" data-tablet-class="row-wrap">
# <div class="col col-2" data-adaptive="1" data-mobile-toggle="col-2 col-1">
# <article class="item item-main item-main- _exist-image" data-image="" data-relevance="" style="background-image:url(https://nplus1.ru/images/2022/06/20/1ac36ac9bb357e6746b6175dceeb338b.jpg)">
# <a data-id="33330" href="/news/2022/06/20/phrynocephalus-mystaceus">
# <div class="caption">
# <div class="date">
# <span class="name" title="2022-06-20">19:42</span>
# </div>
# <h3>Круглоголовки отказались раскрывать «уши» перед сородичами</h3>
# </div>
# </a>
# </article> </div>
# <div class="col col-1 col-ad-prev" data-adaptive="1" data-middle-class="_swap col-1 _indent-bottom">
# <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
# <a data-id="33328" href="/news/2022/06/20/volumetric-avatar">
# <div class="caption">
# <div class="date">
# <span class="name" title="2022-06-20">18:47</span>
# </div>
# <h3>Meta научила смартфоны создавать реалистичную модель лица</h3>
# </div>
# </a>
# </article> <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
# <a data-id="33323" href="/news/2022/06/20/millet">
# <div class="caption">
# <div class="date">
# <span class="name" title="2022-06-20">16:29</span>
# </div>
# <h3>В сосуде из тюркского погребения VII века обнаружили просо</h3>
# </div>
# </a>
# </article> <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
# <a data-id="33329" href="/news/2022/06/20/Spin-charge-separation">
# <div class="caption">
# <div class="date">
# <span class="name" title="2022-06-20">13:10</span>
# </div>
# <h3>Физики подтвердили спин-зарядовое разделение в одномерной квантовой жидкости</h3>
# </div>
# </a>
# </article> </div>
# <div class="col col-1 _tablet-hidden col-ad" data-adaptive="1" data-middle-class="col-1 _swap _indent-bottom" data-mobile-class="col-1 _indent-bottom">
# <div class="ad ad-col border">
# </div>
# </div>
# <div class="col col-1 col-ad-next" data-adaptive="1" data-middle-class="col-full _indent-bottom-no">
# <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
# <a data-id="33290" href="/news/2022/06/20/fatherhood-relationships">
# <div class="caption">
# <div class="date">
# <span class="name" title="2022-06-20">12:50</span>
# </div>
# <h3>Желание стать отцом привлекло женщин для долгосрочных отношений</h3>
# </div>
# </a>
# </article> <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
# <a data-id="33322" href="/news/2022/06/20/escherichia-coli">
# <div class="caption">
# <div class="date">
# <span class="name" title="2022-06-20">11:49</span>
# </div>
# <h3>Биологи прочитали геном кишечной палочки из желчного камня мумии итальянского аристократа</h3>
# </div>
# </a>
# </article> <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
# <a data-id="33319" href="/news/2022/06/20/phiale">
# <div class="caption">
# <div class="date">
# <span class="name" title="2022-06-20">09:49</span>
# </div>
# <h3>Сарматы переделали греческую фиалу в нагрудник церемониального конского снаряжения</h3>
# </div>
# </a>
# </article> </div>
# </div>
# <div class="row" data-adaptive="1" data-middle-class="row-wrap" data-mobile-class="row-wrap" data-tablet-class="row-wrap">
# <!--  fixed 8 -->
# <div class="col col-full">
# <article class="item item-article item-article-stretch _exist-image" data-image="https://nplus1.ru/images/2022/06/16/f8cf9334e576a8240cfdd7709db91d57.jpg" data-relevance="">
# <a data-id="28685" href="/material/2022/06/16/quantumalgorithms">
# <div class="caption">
# <div class="heading">
# <h3>Разминка для кубита</h3>
# <p class="subtitle">О чем сегодня ученые заставляют думать квантовые процессоры </p>
# </div>
# <div class="lead">
# <p>
#                             Чтобы сделать универсальный квантовый вычислитель, нужно решить две проблемы: инструментальную и логическую. Первая — это вопрос о кубитах, о том, из каких квантовых объектов лучше всего делать процессоры для таких вычислителей. Второй — какие вообще задачи можно решать на этих машинах.
#                         </p>
# </div>
# </div>
# </a>
# <nav class="nav-rubricator">
# <ul>
# <li>
# <a class="link-rubric" href="/rubric/physics">Физика</a>
# </li>
# <li>
# <a class="link-theme" href="/theme/alicebobcharlie">Квантовая азбука</a>
# </li>
# </ul>
# </nav>
# </article> </div>
# <!-- /fixed 8 -->
# </div>
# <div class="row" data-adaptive="1" data-middle-class="row-wrap" data-mobile-class="row-wrap" data-tablet-class="row-wrap">
# <div class="col col-1" data-adaptive="1" data-middle-class="col-1 _indent-bottom" data-tablet-class="col-1 _indent-bottom">
# <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
# <a data-id="33320" href="/news/2022/06/19/drone-in-mars-winter">
# <div class="caption">
# <div class="date">
# <span class="name" title="2022-06-19">вчера</span>
# </div>
# <h3>«Индженьюити» совершил первый полет в условиях марсианской зимы</h3>
# </div>
# </a>
# </article> <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
# <a data-id="33317" href="/news/2022/06/18/moon-map">
# <div class="caption">
# <div class="date">
# <span class="name" title="2022-06-18">18 июня</span>
# </div>
# <h3>Китайские астрономы создали детальную геологическую карту Луны</h3>
# </div>
# </a>
# </article> <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
# <a data-id="33318" href="/news/2022/06/18/perovskite-LCP">
# <div class="caption">
# <div class="date">
# <span class="name" title="2022-06-18">18 июня</span>
# </div>
# <h3>Антиоксидант из помидоров продлил жизнь солнечным элементам</h3>
# </div>
# </a>
# </article> </div>
# <div class="col col-1 _swap" data-adaptive="1" data-desktop-swap="0" data-middle-class="col-full" data-tablet-class="col-1 _indent-bottom _indent-right-no" data-tablet-swap="0">
# <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
# <a data-id="33314" href="/news/2022/06/18/hyades-and-sun">
# <div class="caption">
# <div class="date">
# <span class="name" title="2022-06-18">18 июня</span>
# </div>
# <h3>Астрономы уличили скопление Гиады в сближении с Солнечной системой в прошлом</h3>
# </div>
# </a>
# </article> <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
# <a data-id="33316" href="/news/2022/06/18/shangdu">
# <div class="caption">
# <div class="date">
# <span class="name" title="2022-06-18">18 июня</span>
# </div>
# <h3>В некрополе у столицы империи Юань нашли людей европейского происхождения</h3>
# </div>
# </a>
# </article> <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
# <a data-id="33315" href="/news/2022/06/18/drimolen">
# <div class="caption">
# <div class="date">
# <span class="name" title="2022-06-18">18 июня</span>
# </div>
# <h3>Палеоантропологи обнаружили в Колыбели человечества 15 зубов парантропов</h3>
# </div>
# </a>
# </article> </div>
# <!--  fixed 15 -->
# <div class="col col-1" data-adaptive="1">
# <article class="item item-blog item-blog- _exist-image" data-image="" data-relevance="" style="background-image:url(https://nplus1.ru/images/2022/06/20/9a20f3bbc74caf2b1888e91adc9f724c.jpg)">
# <a data-id="33327" href="/blog/2022/06/20/calling-bullshit">
# <div class="caption">
# <div class="heading">
# <p>Ex libris/Книжная полка</p>
# </div>
# <div class="author">
# <img class="avatar" data-mask="avatar90" height="90" src="https://nplus1.ru/images/2017/07/26/5c4d6001f4a0ac4519158089982529c9.jpg" width="90"/>
# <div class="meta">
# <p class="name">Манн, Иванов  и Фербер</p>
# <p class="specs">Научно-популярные книгоиздатели</p>
# </div>
# </div> <div class="lead">
# <p>
#                     Это заблуждение так распространено, что у него появилось название — ошибка прокурора. Наша история объясняет почему. В суде она может быть вопросом жизни и смерти, но это распространенный источник заблуждений при интерпретации данных научных исследований.
#                 </p>
# </div>
# </div>
# </a>
# </article> </div>
# <!-- /fixed 15 -->
# <!--  fixed 16 -->
# <div class="col col-1 _swap" data-adaptive="1" data-middle-swap="0">
# <article class="item item-blog item-blog- _exist-image" data-image="" data-relevance="" style="background-image:url(https://nplus1.ru/images/2022/06/16/bd7a6ca5f08464eb1a4986b5589bb3d8.jpg)">
# <a data-id="33300" href="/blog/2022/06/16/people-and-institutions-of-peters-reform">
# <div class="caption">
# <div class="heading">
# <p>Ex libris/Книжная полка</p>
# </div>
# <div class="author">
# <img class="avatar" data-mask="avatar90" height="90" src="https://nplus1.ru/images/2019/02/26/688309b674c59cc08a4e1980eda70321.jpg" width="90"/>
# <div class="meta">
# <p class="name">НЛО  </p>
# <p class="specs">Книжное издательство</p>
# </div>
# </div> <div class="lead">
# <p>
#                     Угроза оказаться на дыбе по ложному обвинению в «непристойных словах» или в разбое являлась для русского человека в начале XVIII в. не самой актуальной. В большей мере подданные московского царя рисковали пострадать от злоупотреблений представителей власти.
#                 </p>
# </div>
# </div>
# </a>
# </article> </div>
# <!-- /fixed 16 -->
# </div>
# <div class="row" data-adaptive="1" data-middle-class="row-wrap" data-mobile-class="row-wrap" data-tablet-class="row-wrap">
# <!--  fixed 17 -->
# <div class="col col-2" data-adaptive="1" data-middle-toggle="col-2 col-3" data-mobile-toggle="col-2 col-1" data-tablet-class="col-1">
# <article class="item item-article item-article-secondary _exist-image" data-image="https://nplus1.ru/images/2022/06/15/b7d52651bf0db2a09f9b27d643e76358.jpg" data-relevance="" style="background-image:url(https://nplus1.ru/images/2022/06/14/e484431fc516ffe65e3fb74733eee217.jpg)">
# <a data-id="33277" href="/material/2022/06/15/trinityrex">
# <div class="caption">
# <h3>Постулат о трех тирексах</h3>
# <p class="subtitle">Зачем палеонтологи решили поделить тираннозавра на три разных вида</p>
# </div>
# </a>
# <nav class="nav-rubricator">
# <ul>
# <li>
# <a class="link-rubric" href="/rubric/paleontology">Палеонтология</a>
# </li>
# </ul>
# </nav>
# </article> </div>
# <div class="col col-2" data-adaptive="1" data-middle-toggle="col-2 col-1" data-mobile-toggle="col-2 col-1" data-tablet-class="col-1">
# <article class="item item-article item-article-secondary _exist-image" data-image="https://nplus1.ru/images/2022/06/02/0bb8c40b2e48e39599c5a1b5e6acde04.jpg" data-relevance="" style="background-image:url(https://nplus1.ru/images/2022/06/09/0091450377ff8a76b77920b777acfd7c.jpg)">
# <a data-id="33185" href="/material/2022/06/03/deadly-food">
# <div class="caption">
# <h3>Съедобное-несъедобное</h3>
# <p class="subtitle">Выберите блюдо и узнайте, кому оно годится в пищу (и почему)</p>
# </div>
# </a>
# <nav class="nav-rubricator">
# <ul>
# <li>
# <a class="link-rubric" href="/rubric/medicine">Медицина</a>
# </li>
# <li>
# <a class="link-theme" href="/theme/bread-and-wine">Хлеб и вино</a>
# </li>
# </ul>
# </nav>
# </article> </div>
# <!-- /fixed 17 -->
# </div>
# <div class="row" data-adaptive="1" data-middle-class="row-wrap" data-mobile-class="row-wrap" data-tablet-class="row-wrap">
# <div class="col col-1" data-adaptive="1" data-middle-class="col-1 _indent-bottom" data-tablet-class="col-1 _indent-bottom">
# <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
# <a data-id="33310" href="/news/2022/06/17/polar-bears">
# <div class="caption">
# <div class="date">
# <span class="name" title="2022-06-17">17 июня</span>
# </div>
# <h3>Белые медведи с юго-востока Гренландии из-за нехватки морского льда перешли на пресный</h3>
# </div>
# </a>
# </article> <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
# <a data-id="33313" href="/news/2022/06/17/fullerene-monolayer">
# <div class="caption">
# <div class="date">
# <span class="name" title="2022-06-17">17 июня</span>
# </div>
# <h3>Химики получили монослой полимерного фуллерена</h3>
# </div>
# </a>
# </article> <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
# <a data-id="33307" href="/news/2022/06/17/giant-dwarf-crocodiles">
# <div class="caption">
# <div class="date">
# <span class="name" title="2022-06-17">17 июня</span>
# </div>
# <h3>У мелких тупорылых крокодилов нашлись крупные доисторические родственники</h3>
# </div>
# </a>
# </article> </div>
# <div class="col col-1 _swap" data-adaptive="1" data-desktop-swap="0" data-middle-class="col-full" data-tablet-class="col-1 _indent-bottom _indent-right-no" data-tablet-swap="0">
# <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
# <a data-id="33311" href="/news/2022/06/17/mars-debris">
# <div class="caption">
# <div class="date">
# <span class="name" title="2022-06-17">17 июня</span>
# </div>
# <h3>«Персеверанс» отыскал кусок термоизоляции на Марсе</h3>
# </div>
# </a>
# </article> <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
# <a data-id="33308" href="/news/2022/06/17/vision-swimsion">
# <div class="caption">
# <div class="date">
# <span class="name" title="2022-06-17">17 июня</span>
# </div>
# <h3>Четвероногий робот получил модуль для передвижения вплавь</h3>
# </div>
# </a>
# </article> <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
# <a data-id="33312" href="/news/2022/06/17/end-of-cern">
# <div class="caption">
# <div class="date">
# <span class="name" title="2022-06-17">17 июня</span>
# </div>
# <h3>ЦЕРН прекратит 30-летнее сотрудничество с Россией</h3>
# </div>
# </a>
# </article> </div>
# <!--  fixed 24 -->
# <div class="col col-1">
# <article class="item item-blog item-blog- _exist-image" data-image="" data-relevance="" style="background-image:url(https://nplus1.ru/images/2022/06/17/3cb4a948a89fd2084a63485f077981df.jpg)">
# <a data-id="33299" href="/blog/2022/06/17/sberautotech">
# <div class="caption">
# <div class="heading">
# <p>Транспорт/Обеспилочено</p>
# </div>
# <div class="author">
# <img class="avatar" data-mask="avatar90" height="90" src="https://nplus1.ru/images/2018/02/09/205b1e35080689391fbec7e601c089a0.jpg" width="90"/>
# <div class="meta">
# <p class="name">Григорий Копиев</p>
# <p class="specs">редактор</p>
# </div>
# </div> <div class="lead">
# <p>
#                     Машине пришлось столкнуться с тем, ради чего и проводят тесты в городе: реальными водителями. Беспилотник заметил на велодорожке машину с открытой дверью. Он несколько секунд подождал, пока человек закроет дверь, тронулся, но его тут же обогнал и «подрезал» черный «Гелендваген».
#                 </p>
# </div>
# </div>
# </a>
# </article> </div>
# <!-- /fixed 24 -->
# <!--  fixed 25 -->
# <div class="col col-1 _swap" data-adaptive="1" data-middle-class="col-1 _indent-bottom" data-middle-swap="0">
# <article class="item item-blog item-blog- _exist-image" data-image="" data-relevance="" style="background-image:url(https://nplus1.ru/images/2022/06/14/78dfe166c5f9584db419b27fa601b82f.jpg)">
# <a data-id="33278" href="/blog/2022/06/14/eye-of-the-albatross">
# <div class="caption">
# <div class="heading">
# <p>Ex libris/Книжная полка</p>
# </div>
# <div class="author">
# <img class="avatar" data-mask="avatar90" height="90" src="https://nplus1.ru/images/2018/02/06/1ccc6e9960399e0551870d97fc98b306.jpg" width="90"/>
# <div class="meta">
# <p class="name">Альпина нон-фикшн</p>
# <p class="specs">Научно-популярное издательство</p>
# </div>
# </div> <div class="lead">
# <p>
#                     В основном птенцы сидят в гнездах неподвижно: они пускают всю энергию в рост и не тратят понапрасну ни одной калории. Они ужасно беспомощны и мучительно голодны. Многие птенцы неделями ждут еды, пока родители облетают просторы океана, чтобы добыть им пищу.
#                 </p>
# </div>
# </div>
# </a>
# </article> </div>
# <!-- /fixed 25 -->
# </div>
# <div class="row" data-adaptive="1" data-middle-class="row-wrap" data-mobile-class="row-wrap" data-tablet-class="row-wrap">
# <!--  fixed 26 -->
# <div class="col col-2" data-adaptive="1" data-middle-toggle="col-2 col-3" data-mobile-toggle="col-2 col-1" data-tablet-class="col-1">
# <article class="item item-article item-article-secondary _exist-image" data-image="" data-relevance="" style="background-image:url(https://nplus1.ru/images/2022/05/13/5f2e5569956d75df34ef71ab2bb41daf.jpg)">
# <a data-id="32984" href="/news/2022/06/06/are-you-rational">
# <div class="caption">
# <h3>Неразумная экономика</h3>
# <p class="subtitle">Насколько типичны ваши решения о покупках?</p>
# </div>
# </a>
# <nav class="nav-rubricator">
# <ul>
# <li>
# <a class="link-rubric" href="/rubric/partners">Партнерский материал</a>
# </li>
# </ul>
# </nav>
# </article> </div>
# <div class="col col-2" data-adaptive="1" data-middle-toggle="col-2 col-1" data-mobile-toggle="col-2 col-1" data-tablet-class="col-1">
# <article class="item item-article item-article-secondary _exist-image" data-image="https://nplus1.ru/images/2021/12/23/e918cd8f643bb776c703b0c14d7c5fdc.jpg" data-relevance="" style="background-image:url(https://nplus1.ru/images/2021/12/23/7e732caa4fdf74ad46217432667cc6b2.jpg)">
# <a data-id="31777" href="/material/2022/05/25/tequila-car-DIY">
# <div class="caption">
# <h3>Адьос, амигос!</h3>
# <p class="subtitle">Придумайте, как сбежать от рейдеров с помощью альтернативного горючего и подручных деталей</p>
# </div>
# </a>
# <nav class="nav-rubricator">
# <ul>
# <li>
# <a class="link-rubric" href="/rubric/partners">Партнерский материал</a>
# </li>
# <li>
# <a class="link-theme" href="/theme/diy">Сделай сам</a>
# </li>
# </ul>
# </nav>
# </article> </div>
# <!-- /fixed 26 -->
# </div>
# <!-- / dynamic content -->
# </section>
# <!-- / main section -->
# <div id="wrapper-footer">
# <section class="_middle" id="difficult">
# <!-- Slider main container -->
# <div class="swiper-container">
# <!-- Additional required wrapper -->
# <div class="swiper-wrapper">
# <div class="swiper-slide">
# <div class="heading">
# <div class="num">
# <div class="value">9.4</div>
# </div>
# <p>Коэффициент сложности</p>
# </div>
# <h3><a href="/news/2022/06/15/MicroBooNE-against-MiniBooNe">Коллаборация MicroBooNE опровергла избыток электронных нейтрино у MiniBooNe</a></h3>
# </div>
# <div class="swiper-slide">
# <div class="heading">
# <div class="num">
# <div class="value">8.9</div>
# </div>
# <p>Коэффициент сложности</p>
# </div>
# <h3><a href="/news/2022/06/16/MATTG">В магическом трехслойном графене нашли два режима сверхпроводимости</a></h3>
# </div>
# <div class="swiper-slide">
# <div class="heading">
# <div class="num">
# <div class="value">7.7</div>
# </div>
# <p>Коэффициент сложности</p>
# </div>
# <h3><a href="/material/2022/06/16/quantumalgorithms">Разминка для кубита</a></h3>
# </div>
# <div class="swiper-slide">
# <div class="heading">
# <div class="num">
# <div class="value">7.2</div>
# </div>
# <p>Коэффициент сложности</p>
# </div>
# <h3><a href="/news/2022/06/17/isotopic-g-factor-difference">Физики уточнили изотопический сдвиг g-фактора водородоподобного неона</a></h3>
# </div>
# <div class="swiper-slide">
# <div class="heading">
# <div class="num">
# <div class="value">7.1</div>
# </div>
# <p>Коэффициент сложности</p>
# </div>
# <h3><a href="/news/2022/06/20/Spin-charge-separation">Физики подтвердили спин-зарядовое разделение в одномерной квантовой жидкости</a></h3>
# </div>
# <div class="swiper-slide">
# <div class="heading">
# <div class="num">
# <div class="value">6.5</div>
# </div>
# <p>Коэффициент сложности</p>
# </div>
# <h3><a href="/news/2022/06/17/fullerene-monolayer">Химики получили монослой полимерного фуллерена</a></h3>
# </div>
# <div class="swiper-slide">
# <div class="heading">
# <div class="num">
# <div class="value">6.5</div>
# </div>
# <p>Коэффициент сложности</p>
# </div>
# <h3><a href="/news/2022/06/16/1D-He4">Физики сделали жидкий гелий одномерным</a></h3>
# </div>
# <div class="swiper-slide">
# <div class="heading">
# <div class="num">
# <div class="value">6.3</div>
# </div>
# <p>Коэффициент сложности</p>
# </div>
# <h3><a href="/news/2022/06/14/PN-formation">Молекула разложилась с образованием мононитрида фосфора</a></h3>
# </div>
# <div class="swiper-slide">
# <div class="heading">
# <div class="num">
# <div class="value">5.2</div>
# </div>
# <p>Коэффициент сложности</p>
# </div>
# <h3><a href="/news/2022/06/14/hubble-bh-isolated">Астрономы усомнились в природе кандидата в «блуждающую» черную дыру звездной массы</a></h3>
# </div>
# <div class="swiper-slide">
# <div class="heading">
# <div class="num">
# <div class="value">4.9</div>
# </div>
# <p>Коэффициент сложности</p>
# </div>
# <h3><a href="/news/2022/06/15/complex-language">Разговорная речь заставила выбрать между умными словами и сложными предложениями</a></h3>
# </div>
# </div>
# <!-- If we need pagination -->
# <div class="swiper-pagination"></div>
# <div class="swiper-button-prev"></div>
# <div class="swiper-button-next"></div>
# </div>
# <h6>Самое сложное</h6>
# </section>
# <div class="container">
# <div class="line">
# <a class="action-line-toggle" href="https://nplus1.ru/blog/2022/06/16/people-and-institutions-of-peters-reform">
# <div class="heading"><span></span></div>
# </a>
# <a class="container-link" href="https://nplus1.ru/blog/2022/06/16/people-and-institutions-of-peters-reform">
# <div class="heading"><span>Книжная полка</span></div>
# <div class="link"><span>Дмитрий Серов «Люди и учреждения Петровской эпохи»</span></div>
# </a>
# <a class="container-link" href="https://nplus1.ru/blog/2022/06/14/eye-of-the-albatross">
# <div class="heading"><span>Книжная полка</span></div>
# <div class="link"><span>Карл Сафина «Глазами альбатроса»</span></div>
# </a>
# <a class="container-link" href="https://nplus1.ru/blog/2022/06/09/le-theoreme-du-parapluie">
# <div class="heading"><span>Книжная полка</span></div>
# <div class="link"><span>Микаэль Лонэ «Теорема зонтика, или Искусство правильно смотреть на мир через призму математики»</span></div>
# </a>
# <a class="container-link" href="https://nplus1.ru/blog/2022/06/07/dig-for-science">
# <div class="heading"><span>Эксперименты</span></div>
# <div class="link"><span>Кладмен — климатолог: как закапывать чайные пакетики, чтобы побыть своего рода ученым</span></div>
# </a>
# <a class="container-link" href="https://nplus1.ru/blog/2022/06/07/breathing-lessons">
# <div class="heading"><span>Книжная полка</span></div>
# <div class="link"><span>Мейлан Хан «Чудо дыхания. Как работают наши легкие и как поддержать их здоровье»</span></div>
# </a>
# <a class="container-link" href="https://nplus1.ru/blog/2022/06/06/marat-spectrometric-analysis">
# <div class="heading"><span>Эксперименты</span></div>
# <div class="link"><span>У меня в глазу спектрометр: инструкция по разложению света невооруженным взглядом</span></div>
# </a>
# <a class="container-link" href="https://nplus1.ru/blog/2022/06/03/tastes-like-moon">
# <div class="heading"><span>Хлеб и вино</span></div>
# <div class="link"><span>На вкус как Луна: зачем NASA кормило тараканов грунтом</span></div>
# </a>
# <a class="container-link" href="https://nplus1.ru/blog/2022/06/03/from-earth-to-neptune-and-beyond">
# <div class="heading"><span>Книжная полка</span></div>
# <div class="link"><span>Игорь Лисов «Разведчики внешних планет»</span></div>
# </a>
# <a class="container-link" href="https://nplus1.ru/blog/2022/05/31/jellyfish-age-backwards">
# <div class="heading"><span>Книжная полка</span></div>
# <div class="link"><span>Никлас Брендборг «Загадка нестареющей медузы»</span></div>
# </a>
# <a class="container-link active" href="https://nplus1.ru/blog/2022/06/20/calling-bullshit">
# <div class="heading"><span>Книжная полка</span></div>
# <div class="link"><span>Карл Бергстром, Джевин Уэст «Полный бред! Скептицизм в мире больших данных»</span></div>
# </a>
# </div>
# </div>
# <script async="" src="https://cdn.onthe.io/io.js/QCyUUwp6IVuR"></script>
# <script>
# window._io_config = window._io_config || {};
# window._io_config["0.2.0"] = window._io_config["0.2.0"] || [];
# window._io_config["0.2.0"].push({
#     page_url: document.location.toString(),
#     page_url_canonical: document.querySelector('link[rel="canonical"]').href,
#     page_title: document.querySelector('title').innerHTML,
#     page_type: "main",
#     page_language: "ru"
# });
# </script>
# <div class="ad ad-col border">
# </div>
# <!-- footer -->
# <footer id="footer">
# <div class="row" data-adaptive="1" data-middle-class="row-wrap" data-mobile-class="row-wrap" data-tablet-class="row-wrap">
# <div class="col col-logo">
# <a class="link-logo" href="/"><img src="/i/logo-alt.png"/></a>
# </div>
# <div class="col col-footer-desc">
# <nav class="nav-pages">
# <ul>
# <li>
# <a href="/about">О нас</a>
# </li>
# <li>
# <a href="https://nplus.pro" target="_blank">N + Production</a>
# </li>
# <li>
# <a href="/adv">Рекламодателям</a>
# </li>
# <li>
# <a href="/rules">Наши материалы</a>
# </li>
# <li>
# <a href="/vacancy">Вакансии</a>
# </li>
# <li>
# <a href="/blog/2022/04/01/samotek">Авторам</a>
# </li>
# <li>
# <a href="/difficult">Сложность</a>
# </li>
# </ul>
# </nav>
# <div class="desc">
# <p>© 2022 <i>N + 1</i> Интернет-издание   Свидетельство о регистрации СМИ Эл № ФС77-67614</p>
# <p>Использование всех текстовых материалов без изменений в некоммерческих целях разрешается со ссылкой на <i>N + 1</i>.
#                         Все аудиовизуальные произведения являются собственностью своих авторов и правообладателей и используются
#                         только в образовательных и информационных целях. Если вы являетесь собственником того или иного произведения
#                         и не согласны с его размещением на нашем сайте, пожалуйста, напишите на kirill@nplus1.ru</p>
# <p>Материалы, опубликованные в разделе «Блоги», отражают позиции их авторов, которые могут не совпадать с мнением редакции.</p>
# <p>Сайт может содержать контент, не предназначенный для лиц младше 18 лет.</p>
# <p>Связь с редакцией: <a href="mailto:info@nplus1.ru">info@nplus1.ru</a></p>
# <p>
# <a class="pd" href="https://nplus1.ru/personal-data-policy">Политика обработки персональных данных пользователей сайта</a>
# </p>
# <p>
# </p>
# <p>
# </p>
# </div>
# </div>
# <div class="col col-1 pull-right">
# <nav class="nav-social">
# <ul>
# <li>
# <a href="https://t.me/nplusone"><i class="fa fa-telegram"></i></a>
# </li>
# <li>
# <a href="http://vk.com/nplusone"><i class="fa fa-vk"></i></a>
# </li>
# <li>
# <a href="https://twitter.com/nplusodin"><i class="fa fa-twitter"></i></a>
# </li>
# <li>
# <a href="https://ok.ru/nplus1"><i class="fa fa-odnoklassniki"></i></a>
# </li>
# <li>
# <a href="https://soundcloud.com/nplus_1"><i class="fa fa-soundcloud"></i></a>
# </li>
# <li>
# <a href="/rss"><i class="fa fa-rss"></i></a>
# </li>
# </ul>
# </nav>
# <div class="partners">
# <!-- Rating@Mail.ru counter -->
# <script type="text/javascript">
# var _tmr = window._tmr || (window._tmr = []);
# _tmr.push({id: "3084572", type: "pageView", start: (new Date()).getTime()});
# (function (d, w, id) {
#   if (d.getElementById(id)) return;
#   var ts = d.createElement("script"); ts.type = "text/javascript"; ts.async = true; ts.id = id;
#   ts.src = "https://top-fwz1.mail.ru/js/code.js";
#   var f = function () {var s = d.getElementsByTagName("script")[0]; s.parentNode.insertBefore(ts, s);};
#   if (w.opera == "[object Opera]") { d.addEventListener("DOMContentLoaded", f, false); } else { f(); }
# })(document, window, "topmailru-code");
# </script><noscript><div>
# <img alt="Top.Mail.Ru" src="https://top-fwz1.mail.ru/counter?id=3084572;js=na" style="border:0;position:absolute;left:-9999px;"/>
# </div></noscript>
# <!-- //Rating@Mail.ru counter -->
# </div>
# </div>
# </div>
# </footer> <!-- / footer -->
# </div>
# </div>
# </div>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-MNJC58');</script>
# <!-- End Google Tag Manager -->
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-MNJC58" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <noscript><div><img alt="" src="//mc.yandex.ru/watch/29654565" style="position:absolute; left:-9999px;"/></div></noscript>
# <script src="/js/lib/js.cookie.js"></script>
# <script src="/js/lib/jquery.swap.js"></script>
# <script src="/js/lib/swiper.jquery.min.js"></script>
# <script src="/js/lib/svg.js"></script>
# <script src="/js/lib/jquery.mobile-events.min.js"></script>
# <script src="/js/lib/social-likes.min.js"></script>
# <script src="/js/lib/jquery.sticky.js"></script>
# <script src="/js/tests/scopus/js/bundle.js"></script>
# <!--   project scripts -->
# <script src="/js/main.min.js?v=1650440205"></script>
# <!-- / project scripts -->
# <!-- Quantcast Tag -->
# <script type="text/javascript">
# var _qevents = _qevents || [];
#
# (function() {
# var elem = document.createElement('script');
# elem.src = (document.location.protocol == "https:" ? "https://secure" : "http://edge") + ".quantserve.com/quant.js";
# elem.async = true;
# elem.type = "text/javascript";
# var scpt = document.getElementsByTagName('script')[0];
# scpt.parentNode.insertBefore(elem, scpt);
# })();
#
# _qevents.push({
# qacct:"p-s3ftDEFzEW5x7"
# });
# </script>
# <noscript>
# <div style="display:none;">
# <img alt="Quantcast" border="0" height="1" src="//pixel.quantserve.com/pixel/p-s3ftDEFzEW5x7.gif" width="1"/>
# </div>
# </noscript>
# <!-- End Quantcast tag -->
# </body>
# </html>

# %% [markdown]
# Для просмотра выглядит не очень удобно.  «Причешем» наш `soup` – воспользуемся методом `.prettify()` в сочетании с функцией `print()`.

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="old-town-road no-js bg-fixed" lang="" style="background-image:url(none)">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="ie=edge" http-equiv="x-ua-compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="yes" name="apple-mobile-web-app-capable"/>
#   <meta content="black" name="apple-mobile-web-app-status-bar-style"/>
#   <meta content="7991d7eb02d759f05b9050e111a7e3eb" name="wmail-verification"/>
#   <link href="https://nplus1.ru" rel="canonical"/>
#   <link href="/i/favicon-bw.png" rel="icon"/>
#   <title>
#    N + 1: научные статьи, новости, открытия
#   </title>
#   <!-- for Google -->
#   <meta content="N + 1: научные статьи, новости, открытия" name="description"/>
#   <meta content="" name="author"/>
#   <meta content="" name="copyright"/>
#   <!-- for Facebook -->
#   <meta content="N + 1: научные статьи, новости, открытия" property="og:title"/>
#   <meta content="https://nplus1.ru/i/logo.og.png" property="og:image"/>
#   <meta content="https://nplus1.ru" property="og:url"/>
#   <meta content="N + 1: научные статьи, новости, открытия" property="og:description"/>
#   <!-- for Twitter -->
#   <meta content="summary_large_image" name="twitter:card"/>
#   <meta content="@nplusodin" name="twitter:site"/>
#   <meta content="N + 1: научные статьи, новости, открытия" name="twitter:title"/>
#   <meta content="N + 1: научные статьи, новости, открытия" name="twitter:description"/>
#   <meta content="https://nplus1.ru/i/logo.png" name="twitter:image"/>
#   <meta content="8c90b02c84ac3b72" name="yandex-verification"/>
#   <meta content="b419949322895fc9106e24ed01be58ac" name="pmail-verification"/>
#   <link href="https://nplus1.ru/rss" rel="alternate" title="RSS" type="application/rss+xml"/>
#   <link href="/css/font-awesome.min.css" rel="stylesheet"/>
#   <link href="/css/main.min.css?v=1649061972" rel="stylesheet"/>
#   <link href="/css/desktop.min.css?v=1452887696" rel="stylesheet"/>
#   <link href="/css/tablet.min.css?v=1499281342" rel="stylesheet"/>
#   <link href="/css/mobile.min.css?v=1635965090" rel="stylesheet"/>
#   <link href="/js/tests/scopus/css/style.css" rel="stylesheet"/>
#   <script src="//ajax.googleapis.com/ajax/libs/jquery/1.11.2/jquery.min.js">
#   </script>
#   <script src="//cdnjs.cloudflare.com/ajax/libs/modernizr/2.8.3/modernizr.min.js">
#   </script>
#   <script src="/js/lib/adfox.asyn.code.ver3.js" type="text/javascript">
#   </script>
#   <script src="/js/lib/adfox.asyn.code.scroll.js" type="text/javascript">
#   </script>
#   <script crossorigin="anonymous" src="https://yastatic.net/pcode/adfox/loader.js">
#   </script>
#   <script async="" src="//s.luxupcdnc.com/t/common_402.js" type="text/javascript">
#   </script>
#   <!--  ad -->
#   <script type="text/javascript">
#    var __colAdLoaded = false;
# 		    var __topAdLoaded = false;
#
# 		    var __id = "";
#
# 		    function detectAd(id){
# 		        var _ad = document.getElementById("AdFox_banner_"+id);
# 		    	    console.debug(_ad);
#
# 		        __id = id;
# 		        if(_ad != null && _ad.innerHTML == ""){
# 		            $(".col-ad").remove();
# 		        }
# 		        __colAdLoaded = true;
# 		    }
# 		    function detectAdTop(id){
# 		        __topAdLoaded = true;
# 		    }
#   </script>
#   <!-- /ad -->
#   <script type="application/ld+json">
#    { "@context": "http://schema.org", "@type": "WebSite", "url": "https://nplus1.ru", "name": "N + 1: научные статьи, новости, открытия", "description": "N + 1: научные статьи, новости, открытия", "image": "https://nplus1.ru/i/logo.png", "publisher": { "@type": "Organization", "name": "N + 1", "logo": { "@type":"ImageObject", "url": "https://nplus1.ru/i/logo-alt.png" }, "sameAs": [ "https://www.facebook.com/nplusone", "https://twitter.com/nplusodin", "https://vk.com/nplusone", "https://ok.ru/nplus1", "https://soundcloud.com/nplus_1", "https://t.me/nplusone" ] }, "potentialAction":{ "@type":"SearchAction", "target":"https://nplus1.ru/search?q={search_term_string}", "query-input":"required name=search_term_string" } }
#   </script>
#  </head>
#  <body class="_main" style="background-image:url(none)">
#   <div class="shadow-overlay">
#   </div>
#   <div id="viewport">
#    <div id="shadow">
#    </div>
#    <div class="ad ad-top">
#     <!--AdFox START-->
#     <!--yandex_nplus1adv-->
#     <!--Площадка: N + 1 / * / *-->
#     <!--Тип баннера: Растяжка_100%х250-->
#     <!--Расположение: <верх страницы>-->
#     <div id="adfox_162739969569252320">
#     </div>
#     <script>
#      window.yaContextCb.push(()=>{
#         Ya.adfoxCode.create({
#             ownerId: 386110,
#         containerId: 'adfox_162739969569252320',
#             params: {
#                 pp: 'g',
#             ps: 'fbio',
#             p2: 'hhkj'
#             }
#         })
#     })
#     </script>
#    </div>
#    <header id="header-mobile">
#     <div class="container">
#      <a class="action-menu pull-left" href="#">
#       <i class="icon icon-navicon">
#       </i>
#      </a>
#      <a class="link-logo" href="/">
#       <img src="/i/logo-mobile.png"/>
#      </a>
#      <a class="action-search pull-right" href="#">
#       <i class="icon icon-search">
#       </i>
#      </a>
#      <form action="/search" class="form-search" method="get">
#       <div class="control">
#        <input name="q" placeholder="Найти" type="text" value=""/>
#       </div>
#       <a class="action-search-close" href="#">
#        ×
#       </a>
#      </form>
#     </div>
#     <nav class="nav-rubrics">
#      <ul>
#       <li>
#        <a class="" href="/rubric/astronomy">
#         Астрономия
#        </a>
#       </li>
#       <li>
#        <a class="" href="/rubric/physics">
#         Физика
#        </a>
#       </li>
#       <li>
#        <a class="" href="/rubric/biology">
#         Биология
#        </a>
#       </li>
#       <li>
#        <a class="" href="/rubric/robots-drones">
#         Роботы и дроны
#        </a>
#       </li>
#       <li>
#        <a class="" href="/theme/bookshelf">
#         Книжная полка
#        </a>
#       </li>
#       <li>
#        <a class="" href="/theme/Courses">
#         Курсы
#        </a>
#       </li>
#       <li>
#        <a class="" href="/theme/coronavirus-history">
#         Коронавирусные хроники
#        </a>
#       </li>
#       <li>
#        <a class="" href="/theme/offline">
#         N + Offline
#        </a>
#       </li>
#      </ul>
#     </nav>
#    </header>
#    <div class="js-mediator-container" id="layout">
#     <!-- header -->
#     <header class="_middle" id="header">
#      <div class="row">
#       <div class="col col-logo">
#        <a class="link-logo" href="/">
#        </a>
#       </div>
#       <div class="col col-nav-main">
#        <form action="/search" class="form-search" method="get">
#         <div class="control">
#          <input name="q" placeholder="Найти" type="text" value=""/>
#         </div>
#         <a class="action-search-close" href="#">
#          ×
#         </a>
#        </form>
#        <nav class="nav-rubrics">
#         <ul>
#          <li>
#           <a class="" href="/rubric/astronomy">
#            Астрономия
#           </a>
#          </li>
#          <li>
#           <a class="" href="/rubric/physics">
#            Физика
#           </a>
#          </li>
#          <li>
#           <a class="" href="/rubric/biology">
#            Биология
#           </a>
#          </li>
#          <li>
#           <a class="" href="/rubric/robots-drones">
#            Роботы и дроны
#           </a>
#          </li>
#          <li>
#           <a class="action-search" href="#">
#            <i class="icon icon-search">
#            </i>
#           </a>
#          </li>
#         </ul>
#        </nav>
#        <nav class="nav-themes">
#         <ul>
#          <li data-name="bookshelf">
#           <a class="" href="/theme/bookshelf">
#            Книжная полка
#           </a>
#          </li>
#          <li data-name="Courses">
#           <a class="" href="/theme/Courses">
#            Курсы
#           </a>
#          </li>
#          <li data-name="coronavirus-history">
#           <a class="" href="/theme/coronavirus-history">
#            Коронавирусные хроники
#           </a>
#          </li>
#          <li data-name="offline">
#           <a class="" href="/theme/offline">
#            N + Offline
#           </a>
#          </li>
#         </ul>
#        </nav>
#       </div>
#      </div>
#      <div class="container line-up">
#       <div class="line line-second">
#        <a class="action-line-toggle" href="https://nplus1.ru/blog/2022/06/16/people-and-institutions-of-peters-reform">
#         <div class="heading">
#          <span>
#          </span>
#         </div>
#        </a>
#        <a class="container-link" href="https://nplus1.ru/blog/2022/06/16/people-and-institutions-of-peters-reform">
#         <div class="heading">
#          <span>
#           Книжная полка
#          </span>
#         </div>
#         <div class="link">
#          <span>
#           Дмитрий Серов «Люди и учреждения Петровской эпохи»
#          </span>
#         </div>
#        </a>
#        <a class="container-link" href="https://nplus1.ru/blog/2022/06/14/eye-of-the-albatross">
#         <div class="heading">
#          <span>
#           Книжная полка
#          </span>
#         </div>
#         <div class="link">
#          <span>
#           Карл Сафина «Глазами альбатроса»
#          </span>
#         </div>
#        </a>
#        <a class="container-link" href="https://nplus1.ru/blog/2022/06/09/le-theoreme-du-parapluie">
#         <div class="heading">
#          <span>
#           Книжная полка
#          </span>
#         </div>
#         <div class="link">
#          <span>
#           Микаэль Лонэ «Теорема зонтика, или Искусство правильно смотреть на мир через призму математики»
#          </span>
#         </div>
#        </a>
#        <a class="container-link" href="https://nplus1.ru/blog/2022/06/07/dig-for-science">
#         <div class="heading">
#          <span>
#           Эксперименты
#          </span>
#         </div>
#         <div class="link">
#          <span>
#           Кладмен — климатолог: как закапывать чайные пакетики, чтобы побыть своего рода ученым
#          </span>
#         </div>
#        </a>
#        <a class="container-link" href="https://nplus1.ru/blog/2022/06/07/breathing-lessons">
#         <div class="heading">
#          <span>
#           Книжная полка
#          </span>
#         </div>
#         <div class="link">
#          <span>
#           Мейлан Хан «Чудо дыхания. Как работают наши легкие и как поддержать их здоровье»
#          </span>
#         </div>
#        </a>
#        <a class="container-link" href="https://nplus1.ru/blog/2022/06/06/marat-spectrometric-analysis">
#         <div class="heading">
#          <span>
#           Эксперименты
#          </span>
#         </div>
#         <div class="link">
#          <span>
#           У меня в глазу спектрометр: инструкция по разложению света невооруженным взглядом
#          </span>
#         </div>
#        </a>
#        <a class="container-link" href="https://nplus1.ru/blog/2022/06/03/tastes-like-moon">
#         <div class="heading">
#          <span>
#           Хлеб и вино
#          </span>
#         </div>
#         <div class="link">
#          <span>
#           На вкус как Луна: зачем NASA кормило тараканов грунтом
#          </span>
#         </div>
#        </a>
#        <a class="container-link" href="https://nplus1.ru/blog/2022/06/03/from-earth-to-neptune-and-beyond">
#         <div class="heading">
#          <span>
#           Книжная полка
#          </span>
#         </div>
#         <div class="link">
#          <span>
#           Игорь Лисов «Разведчики внешних планет»
#          </span>
#         </div>
#        </a>
#        <a class="container-link" href="https://nplus1.ru/blog/2022/05/31/jellyfish-age-backwards">
#         <div class="heading">
#          <span>
#           Книжная полка
#          </span>
#         </div>
#         <div class="link">
#          <span>
#           Никлас Брендборг «Загадка нестареющей медузы»
#          </span>
#         </div>
#        </a>
#        <a class="container-link active" href="https://nplus1.ru/blog/2022/06/20/calling-bullshit">
#         <div class="heading">
#          <span>
#           Книжная полка
#          </span>
#         </div>
#         <div class="link">
#          <span>
#           Карл Бергстром, Джевин Уэст «Полный бред! Скептицизм в мире больших данных»
#          </span>
#         </div>
#        </a>
#        <!-- here -->
#       </div>
#      </div>
#     </header>
#     <!-- /header -->
#     <!--  hero -->
#     <!-- /hero -->
#     <!-- main section -->
#     <section id="main">
#      <!--   dynamic content -->
#      <div class="row" data-adaptive="1" data-middle-class="row-wrap _indent-bottom-no" data-mobile-class="row-wrap" data-tablet-class="row-wrap">
#       <div class="col col-2" data-adaptive="1" data-mobile-toggle="col-2 col-1">
#        <article class="item item-main item-main- _exist-image" data-image="" data-relevance="" style="background-image:url(https://nplus1.ru/images/2022/06/20/1ac36ac9bb357e6746b6175dceeb338b.jpg)">
#         <a data-id="33330" href="/news/2022/06/20/phrynocephalus-mystaceus">
#          <div class="caption">
#           <div class="date">
#            <span class="name" title="2022-06-20">
#             19:42
#            </span>
#           </div>
#           <h3>
#            Круглоголовки отказались раскрывать «уши» перед сородичами
#           </h3>
#          </div>
#         </a>
#        </article>
#       </div>
#       <div class="col col-1 col-ad-prev" data-adaptive="1" data-middle-class="_swap col-1 _indent-bottom">
#        <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
#         <a data-id="33328" href="/news/2022/06/20/volumetric-avatar">
#          <div class="caption">
#           <div class="date">
#            <span class="name" title="2022-06-20">
#             18:47
#            </span>
#           </div>
#           <h3>
#            Meta научила смартфоны создавать реалистичную модель лица
#           </h3>
#          </div>
#         </a>
#        </article>
#        <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
#         <a data-id="33323" href="/news/2022/06/20/millet">
#          <div class="caption">
#           <div class="date">
#            <span class="name" title="2022-06-20">
#             16:29
#            </span>
#           </div>
#           <h3>
#            В сосуде из тюркского погребения VII века обнаружили просо
#           </h3>
#          </div>
#         </a>
#        </article>
#        <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
#         <a data-id="33329" href="/news/2022/06/20/Spin-charge-separation">
#          <div class="caption">
#           <div class="date">
#            <span class="name" title="2022-06-20">
#             13:10
#            </span>
#           </div>
#           <h3>
#            Физики подтвердили спин-зарядовое разделение в одномерной квантовой жидкости
#           </h3>
#          </div>
#         </a>
#        </article>
#       </div>
#       <div class="col col-1 _tablet-hidden col-ad" data-adaptive="1" data-middle-class="col-1 _swap _indent-bottom" data-mobile-class="col-1 _indent-bottom">
#        <div class="ad ad-col border">
#        </div>
#       </div>
#       <div class="col col-1 col-ad-next" data-adaptive="1" data-middle-class="col-full _indent-bottom-no">
#        <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
#         <a data-id="33290" href="/news/2022/06/20/fatherhood-relationships">
#          <div class="caption">
#           <div class="date">
#            <span class="name" title="2022-06-20">
#             12:50
#            </span>
#           </div>
#           <h3>
#            Желание стать отцом привлекло женщин для долгосрочных отношений
#           </h3>
#          </div>
#         </a>
#        </article>
#        <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
#         <a data-id="33322" href="/news/2022/06/20/escherichia-coli">
#          <div class="caption">
#           <div class="date">
#            <span class="name" title="2022-06-20">
#             11:49
#            </span>
#           </div>
#           <h3>
#            Биологи прочитали геном кишечной палочки из желчного камня мумии итальянского аристократа
#           </h3>
#          </div>
#         </a>
#        </article>
#        <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
#         <a data-id="33319" href="/news/2022/06/20/phiale">
#          <div class="caption">
#           <div class="date">
#            <span class="name" title="2022-06-20">
#             09:49
#            </span>
#           </div>
#           <h3>
#            Сарматы переделали греческую фиалу в нагрудник церемониального конского снаряжения
#           </h3>
#          </div>
#         </a>
#        </article>
#       </div>
#      </div>
#      <div class="row" data-adaptive="1" data-middle-class="row-wrap" data-mobile-class="row-wrap" data-tablet-class="row-wrap">
#       <!--  fixed 8 -->
#       <div class="col col-full">
#        <article class="item item-article item-article-stretch _exist-image" data-image="https://nplus1.ru/images/2022/06/16/f8cf9334e576a8240cfdd7709db91d57.jpg" data-relevance="">
#         <a data-id="28685" href="/material/2022/06/16/quantumalgorithms">
#          <div class="caption">
#           <div class="heading">
#            <h3>
#             Разминка для кубита
#            </h3>
#            <p class="subtitle">
#             О чем сегодня ученые заставляют думать квантовые процессоры
#            </p>
#           </div>
#           <div class="lead">
#            <p>
#             Чтобы сделать универсальный квантовый вычислитель, нужно решить две проблемы: инструментальную и логическую. Первая — это вопрос о кубитах, о том, из каких квантовых объектов лучше всего делать процессоры для таких вычислителей. Второй — какие вообще задачи можно решать на этих машинах.
#            </p>
#           </div>
#          </div>
#         </a>
#         <nav class="nav-rubricator">
#          <ul>
#           <li>
#            <a class="link-rubric" href="/rubric/physics">
#             Физика
#            </a>
#           </li>
#           <li>
#            <a class="link-theme" href="/theme/alicebobcharlie">
#             Квантовая азбука
#            </a>
#           </li>
#          </ul>
#         </nav>
#        </article>
#       </div>
#       <!-- /fixed 8 -->
#      </div>
#      <div class="row" data-adaptive="1" data-middle-class="row-wrap" data-mobile-class="row-wrap" data-tablet-class="row-wrap">
#       <div class="col col-1" data-adaptive="1" data-middle-class="col-1 _indent-bottom" data-tablet-class="col-1 _indent-bottom">
#        <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
#         <a data-id="33320" href="/news/2022/06/19/drone-in-mars-winter">
#          <div class="caption">
#           <div class="date">
#            <span class="name" title="2022-06-19">
#             вчера
#            </span>
#           </div>
#           <h3>
#            «Индженьюити» совершил первый полет в условиях марсианской зимы
#           </h3>
#          </div>
#         </a>
#        </article>
#        <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
#         <a data-id="33317" href="/news/2022/06/18/moon-map">
#          <div class="caption">
#           <div class="date">
#            <span class="name" title="2022-06-18">
#             18 июня
#            </span>
#           </div>
#           <h3>
#            Китайские астрономы создали детальную геологическую карту Луны
#           </h3>
#          </div>
#         </a>
#        </article>
#        <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
#         <a data-id="33318" href="/news/2022/06/18/perovskite-LCP">
#          <div class="caption">
#           <div class="date">
#            <span class="name" title="2022-06-18">
#             18 июня
#            </span>
#           </div>
#           <h3>
#            Антиоксидант из помидоров продлил жизнь солнечным элементам
#           </h3>
#          </div>
#         </a>
#        </article>
#       </div>
#       <div class="col col-1 _swap" data-adaptive="1" data-desktop-swap="0" data-middle-class="col-full" data-tablet-class="col-1 _indent-bottom _indent-right-no" data-tablet-swap="0">
#        <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
#         <a data-id="33314" href="/news/2022/06/18/hyades-and-sun">
#          <div class="caption">
#           <div class="date">
#            <span class="name" title="2022-06-18">
#             18 июня
#            </span>
#           </div>
#           <h3>
#            Астрономы уличили скопление Гиады в сближении с Солнечной системой в прошлом
#           </h3>
#          </div>
#         </a>
#        </article>
#        <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
#         <a data-id="33316" href="/news/2022/06/18/shangdu">
#          <div class="caption">
#           <div class="date">
#            <span class="name" title="2022-06-18">
#             18 июня
#            </span>
#           </div>
#           <h3>
#            В некрополе у столицы империи Юань нашли людей европейского происхождения
#           </h3>
#          </div>
#         </a>
#        </article>
#        <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
#         <a data-id="33315" href="/news/2022/06/18/drimolen">
#          <div class="caption">
#           <div class="date">
#            <span class="name" title="2022-06-18">
#             18 июня
#            </span>
#           </div>
#           <h3>
#            Палеоантропологи обнаружили в Колыбели человечества 15 зубов парантропов
#           </h3>
#          </div>
#         </a>
#        </article>
#       </div>
#       <!--  fixed 15 -->
#       <div class="col col-1" data-adaptive="1">
#        <article class="item item-blog item-blog- _exist-image" data-image="" data-relevance="" style="background-image:url(https://nplus1.ru/images/2022/06/20/9a20f3bbc74caf2b1888e91adc9f724c.jpg)">
#         <a data-id="33327" href="/blog/2022/06/20/calling-bullshit">
#          <div class="caption">
#           <div class="heading">
#            <p>
#             Ex libris/Книжная полка
#            </p>
#           </div>
#           <div class="author">
#            <img class="avatar" data-mask="avatar90" height="90" src="https://nplus1.ru/images/2017/07/26/5c4d6001f4a0ac4519158089982529c9.jpg" width="90"/>
#            <div class="meta">
#             <p class="name">
#              Манн, Иванов  и Фербер
#             </p>
#             <p class="specs">
#              Научно-популярные книгоиздатели
#             </p>
#            </div>
#           </div>
#           <div class="lead">
#            <p>
#             Это заблуждение так распространено, что у него появилось название — ошибка прокурора. Наша история объясняет почему. В суде она может быть вопросом жизни и смерти, но это распространенный источник заблуждений при интерпретации данных научных исследований.
#            </p>
#           </div>
#          </div>
#         </a>
#        </article>
#       </div>
#       <!-- /fixed 15 -->
#       <!--  fixed 16 -->
#       <div class="col col-1 _swap" data-adaptive="1" data-middle-swap="0">
#        <article class="item item-blog item-blog- _exist-image" data-image="" data-relevance="" style="background-image:url(https://nplus1.ru/images/2022/06/16/bd7a6ca5f08464eb1a4986b5589bb3d8.jpg)">
#         <a data-id="33300" href="/blog/2022/06/16/people-and-institutions-of-peters-reform">
#          <div class="caption">
#           <div class="heading">
#            <p>
#             Ex libris/Книжная полка
#            </p>
#           </div>
#           <div class="author">
#            <img class="avatar" data-mask="avatar90" height="90" src="https://nplus1.ru/images/2019/02/26/688309b674c59cc08a4e1980eda70321.jpg" width="90"/>
#            <div class="meta">
#             <p class="name">
#              НЛО
#             </p>
#             <p class="specs">
#              Книжное издательство
#             </p>
#            </div>
#           </div>
#           <div class="lead">
#            <p>
#             Угроза оказаться на дыбе по ложному обвинению в «непристойных словах» или в разбое являлась для русского человека в начале XVIII в. не самой актуальной. В большей мере подданные московского царя рисковали пострадать от злоупотреблений представителей власти.
#            </p>
#           </div>
#          </div>
#         </a>
#        </article>
#       </div>
#       <!-- /fixed 16 -->
#      </div>
#      <div class="row" data-adaptive="1" data-middle-class="row-wrap" data-mobile-class="row-wrap" data-tablet-class="row-wrap">
#       <!--  fixed 17 -->
#       <div class="col col-2" data-adaptive="1" data-middle-toggle="col-2 col-3" data-mobile-toggle="col-2 col-1" data-tablet-class="col-1">
#        <article class="item item-article item-article-secondary _exist-image" data-image="https://nplus1.ru/images/2022/06/15/b7d52651bf0db2a09f9b27d643e76358.jpg" data-relevance="" style="background-image:url(https://nplus1.ru/images/2022/06/14/e484431fc516ffe65e3fb74733eee217.jpg)">
#         <a data-id="33277" href="/material/2022/06/15/trinityrex">
#          <div class="caption">
#           <h3>
#            Постулат о трех тирексах
#           </h3>
#           <p class="subtitle">
#            Зачем палеонтологи решили поделить тираннозавра на три разных вида
#           </p>
#          </div>
#         </a>
#         <nav class="nav-rubricator">
#          <ul>
#           <li>
#            <a class="link-rubric" href="/rubric/paleontology">
#             Палеонтология
#            </a>
#           </li>
#          </ul>
#         </nav>
#        </article>
#       </div>
#       <div class="col col-2" data-adaptive="1" data-middle-toggle="col-2 col-1" data-mobile-toggle="col-2 col-1" data-tablet-class="col-1">
#        <article class="item item-article item-article-secondary _exist-image" data-image="https://nplus1.ru/images/2022/06/02/0bb8c40b2e48e39599c5a1b5e6acde04.jpg" data-relevance="" style="background-image:url(https://nplus1.ru/images/2022/06/09/0091450377ff8a76b77920b777acfd7c.jpg)">
#         <a data-id="33185" href="/material/2022/06/03/deadly-food">
#          <div class="caption">
#           <h3>
#            Съедобное-несъедобное
#           </h3>
#           <p class="subtitle">
#            Выберите блюдо и узнайте, кому оно годится в пищу (и почему)
#           </p>
#          </div>
#         </a>
#         <nav class="nav-rubricator">
#          <ul>
#           <li>
#            <a class="link-rubric" href="/rubric/medicine">
#             Медицина
#            </a>
#           </li>
#           <li>
#            <a class="link-theme" href="/theme/bread-and-wine">
#             Хлеб и вино
#            </a>
#           </li>
#          </ul>
#         </nav>
#        </article>
#       </div>
#       <!-- /fixed 17 -->
#      </div>
#      <div class="row" data-adaptive="1" data-middle-class="row-wrap" data-mobile-class="row-wrap" data-tablet-class="row-wrap">
#       <div class="col col-1" data-adaptive="1" data-middle-class="col-1 _indent-bottom" data-tablet-class="col-1 _indent-bottom">
#        <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
#         <a data-id="33310" href="/news/2022/06/17/polar-bears">
#          <div class="caption">
#           <div class="date">
#            <span class="name" title="2022-06-17">
#             17 июня
#            </span>
#           </div>
#           <h3>
#            Белые медведи с юго-востока Гренландии из-за нехватки морского льда перешли на пресный
#           </h3>
#          </div>
#         </a>
#        </article>
#        <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
#         <a data-id="33313" href="/news/2022/06/17/fullerene-monolayer">
#          <div class="caption">
#           <div class="date">
#            <span class="name" title="2022-06-17">
#             17 июня
#            </span>
#           </div>
#           <h3>
#            Химики получили монослой полимерного фуллерена
#           </h3>
#          </div>
#         </a>
#        </article>
#        <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
#         <a data-id="33307" href="/news/2022/06/17/giant-dwarf-crocodiles">
#          <div class="caption">
#           <div class="date">
#            <span class="name" title="2022-06-17">
#             17 июня
#            </span>
#           </div>
#           <h3>
#            У мелких тупорылых крокодилов нашлись крупные доисторические родственники
#           </h3>
#          </div>
#         </a>
#        </article>
#       </div>
#       <div class="col col-1 _swap" data-adaptive="1" data-desktop-swap="0" data-middle-class="col-full" data-tablet-class="col-1 _indent-bottom _indent-right-no" data-tablet-swap="0">
#        <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
#         <a data-id="33311" href="/news/2022/06/17/mars-debris">
#          <div class="caption">
#           <div class="date">
#            <span class="name" title="2022-06-17">
#             17 июня
#            </span>
#           </div>
#           <h3>
#            «Персеверанс» отыскал кусок термоизоляции на Марсе
#           </h3>
#          </div>
#         </a>
#        </article>
#        <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
#         <a data-id="33308" href="/news/2022/06/17/vision-swimsion">
#          <div class="caption">
#           <div class="date">
#            <span class="name" title="2022-06-17">
#             17 июня
#            </span>
#           </div>
#           <h3>
#            Четвероногий робот получил модуль для передвижения вплавь
#           </h3>
#          </div>
#         </a>
#        </article>
#        <article class="item item-news item-news- _exist-image" data-image="" data-relevance="">
#         <a data-id="33312" href="/news/2022/06/17/end-of-cern">
#          <div class="caption">
#           <div class="date">
#            <span class="name" title="2022-06-17">
#             17 июня
#            </span>
#           </div>
#           <h3>
#            ЦЕРН прекратит 30-летнее сотрудничество с Россией
#           </h3>
#          </div>
#         </a>
#        </article>
#       </div>
#       <!--  fixed 24 -->
#       <div class="col col-1">
#        <article class="item item-blog item-blog- _exist-image" data-image="" data-relevance="" style="background-image:url(https://nplus1.ru/images/2022/06/17/3cb4a948a89fd2084a63485f077981df.jpg)">
#         <a data-id="33299" href="/blog/2022/06/17/sberautotech">
#          <div class="caption">
#           <div class="heading">
#            <p>
#             Транспорт/Обеспилочено
#            </p>
#           </div>
#           <div class="author">
#            <img class="avatar" data-mask="avatar90" height="90" src="https://nplus1.ru/images/2018/02/09/205b1e35080689391fbec7e601c089a0.jpg" width="90"/>
#            <div class="meta">
#             <p class="name">
#              Григорий Копиев
#             </p>
#             <p class="specs">
#              редактор
#             </p>
#            </div>
#           </div>
#           <div class="lead">
#            <p>
#             Машине пришлось столкнуться с тем, ради чего и проводят тесты в городе: реальными водителями. Беспилотник заметил на велодорожке машину с открытой дверью. Он несколько секунд подождал, пока человек закроет дверь, тронулся, но его тут же обогнал и «подрезал» черный «Гелендваген».
#            </p>
#           </div>
#          </div>
#         </a>
#        </article>
#       </div>
#       <!-- /fixed 24 -->
#       <!--  fixed 25 -->
#       <div class="col col-1 _swap" data-adaptive="1" data-middle-class="col-1 _indent-bottom" data-middle-swap="0">
#        <article class="item item-blog item-blog- _exist-image" data-image="" data-relevance="" style="background-image:url(https://nplus1.ru/images/2022/06/14/78dfe166c5f9584db419b27fa601b82f.jpg)">
#         <a data-id="33278" href="/blog/2022/06/14/eye-of-the-albatross">
#          <div class="caption">
#           <div class="heading">
#            <p>
#             Ex libris/Книжная полка
#            </p>
#           </div>
#           <div class="author">
#            <img class="avatar" data-mask="avatar90" height="90" src="https://nplus1.ru/images/2018/02/06/1ccc6e9960399e0551870d97fc98b306.jpg" width="90"/>
#            <div class="meta">
#             <p class="name">
#              Альпина нон-фикшн
#             </p>
#             <p class="specs">
#              Научно-популярное издательство
#             </p>
#            </div>
#           </div>
#           <div class="lead">
#            <p>
#             В основном птенцы сидят в гнездах неподвижно: они пускают всю энергию в рост и не тратят понапрасну ни одной калории. Они ужасно беспомощны и мучительно голодны. Многие птенцы неделями ждут еды, пока родители облетают просторы океана, чтобы добыть им пищу.
#            </p>
#           </div>
#          </div>
#         </a>
#        </article>
#       </div>
#       <!-- /fixed 25 -->
#      </div>
#      <div class="row" data-adaptive="1" data-middle-class="row-wrap" data-mobile-class="row-wrap" data-tablet-class="row-wrap">
#       <!--  fixed 26 -->
#       <div class="col col-2" data-adaptive="1" data-middle-toggle="col-2 col-3" data-mobile-toggle="col-2 col-1" data-tablet-class="col-1">
#        <article class="item item-article item-article-secondary _exist-image" data-image="" data-relevance="" style="background-image:url(https://nplus1.ru/images/2022/05/13/5f2e5569956d75df34ef71ab2bb41daf.jpg)">
#         <a data-id="32984" href="/news/2022/06/06/are-you-rational">
#          <div class="caption">
#           <h3>
#            Неразумная экономика
#           </h3>
#           <p class="subtitle">
#            Насколько типичны ваши решения о покупках?
#           </p>
#          </div>
#         </a>
#         <nav class="nav-rubricator">
#          <ul>
#           <li>
#            <a class="link-rubric" href="/rubric/partners">
#             Партнерский материал
#            </a>
#           </li>
#          </ul>
#         </nav>
#        </article>
#       </div>
#       <div class="col col-2" data-adaptive="1" data-middle-toggle="col-2 col-1" data-mobile-toggle="col-2 col-1" data-tablet-class="col-1">
#        <article class="item item-article item-article-secondary _exist-image" data-image="https://nplus1.ru/images/2021/12/23/e918cd8f643bb776c703b0c14d7c5fdc.jpg" data-relevance="" style="background-image:url(https://nplus1.ru/images/2021/12/23/7e732caa4fdf74ad46217432667cc6b2.jpg)">
#         <a data-id="31777" href="/material/2022/05/25/tequila-car-DIY">
#          <div class="caption">
#           <h3>
#            Адьос, амигос!
#           </h3>
#           <p class="subtitle">
#            Придумайте, как сбежать от рейдеров с помощью альтернативного горючего и подручных деталей
#           </p>
#          </div>
#         </a>
#         <nav class="nav-rubricator">
#          <ul>
#           <li>
#            <a class="link-rubric" href="/rubric/partners">
#             Партнерский материал
#            </a>
#           </li>
#           <li>
#            <a class="link-theme" href="/theme/diy">
#             Сделай сам
#            </a>
#           </li>
#          </ul>
#         </nav>
#        </article>
#       </div>
#       <!-- /fixed 26 -->
#      </div>
#      <!-- / dynamic content -->
#     </section>
#     <!-- / main section -->
#     <div id="wrapper-footer">
#      <section class="_middle" id="difficult">
#       <!-- Slider main container -->
#       <div class="swiper-container">
#        <!-- Additional required wrapper -->
#        <div class="swiper-wrapper">
#         <div class="swiper-slide">
#          <div class="heading">
#           <div class="num">
#            <div class="value">
#             9.4
#            </div>
#           </div>
#           <p>
#            Коэффициент сложности
#           </p>
#          </div>
#          <h3>
#           <a href="/news/2022/06/15/MicroBooNE-against-MiniBooNe">
#            Коллаборация MicroBooNE опровергла избыток электронных нейтрино у MiniBooNe
#           </a>
#          </h3>
#         </div>
#         <div class="swiper-slide">
#          <div class="heading">
#           <div class="num">
#            <div class="value">
#             8.9
#            </div>
#           </div>
#           <p>
#            Коэффициент сложности
#           </p>
#          </div>
#          <h3>
#           <a href="/news/2022/06/16/MATTG">
#            В магическом трехслойном графене нашли два режима сверхпроводимости
#           </a>
#          </h3>
#         </div>
#         <div class="swiper-slide">
#          <div class="heading">
#           <div class="num">
#            <div class="value">
#             7.7
#            </div>
#           </div>
#           <p>
#            Коэффициент сложности
#           </p>
#          </div>
#          <h3>
#           <a href="/material/2022/06/16/quantumalgorithms">
#            Разминка для кубита
#           </a>
#          </h3>
#         </div>
#         <div class="swiper-slide">
#          <div class="heading">
#           <div class="num">
#            <div class="value">
#             7.2
#            </div>
#           </div>
#           <p>
#            Коэффициент сложности
#           </p>
#          </div>
#          <h3>
#           <a href="/news/2022/06/17/isotopic-g-factor-difference">
#            Физики уточнили изотопический сдвиг g-фактора водородоподобного неона
#           </a>
#          </h3>
#         </div>
#         <div class="swiper-slide">
#          <div class="heading">
#           <div class="num">
#            <div class="value">
#             7.1
#            </div>
#           </div>
#           <p>
#            Коэффициент сложности
#           </p>
#          </div>
#          <h3>
#           <a href="/news/2022/06/20/Spin-charge-separation">
#            Физики подтвердили спин-зарядовое разделение в одномерной квантовой жидкости
#           </a>
#          </h3>
#         </div>
#         <div class="swiper-slide">
#          <div class="heading">
#           <div class="num">
#            <div class="value">
#             6.5
#            </div>
#           </div>
#           <p>
#            Коэффициент сложности
#           </p>
#          </div>
#          <h3>
#           <a href="/news/2022/06/17/fullerene-monolayer">
#            Химики получили монослой полимерного фуллерена
#           </a>
#          </h3>
#         </div>
#         <div class="swiper-slide">
#          <div class="heading">
#           <div class="num">
#            <div class="value">
#             6.5
#            </div>
#           </div>
#           <p>
#            Коэффициент сложности
#           </p>
#          </div>
#          <h3>
#           <a href="/news/2022/06/16/1D-He4">
#            Физики сделали жидкий гелий одномерным
#           </a>
#          </h3>
#         </div>
#         <div class="swiper-slide">
#          <div class="heading">
#           <div class="num">
#            <div class="value">
#             6.3
#            </div>
#           </div>
#           <p>
#            Коэффициент сложности
#           </p>
#          </div>
#          <h3>
#           <a href="/news/2022/06/14/PN-formation">
#            Молекула разложилась с образованием мононитрида фосфора
#           </a>
#          </h3>
#         </div>
#         <div class="swiper-slide">
#          <div class="heading">
#           <div class="num">
#            <div class="value">
#             5.2
#            </div>
#           </div>
#           <p>
#            Коэффициент сложности
#           </p>
#          </div>
#          <h3>
#           <a href="/news/2022/06/14/hubble-bh-isolated">
#            Астрономы усомнились в природе кандидата в «блуждающую» черную дыру звездной массы
#           </a>
#          </h3>
#         </div>
#         <div class="swiper-slide">
#          <div class="heading">
#           <div class="num">
#            <div class="value">
#             4.9
#            </div>
#           </div>
#           <p>
#            Коэффициент сложности
#           </p>
#          </div>
#          <h3>
#           <a href="/news/2022/06/15/complex-language">
#            Разговорная речь заставила выбрать между умными словами и сложными предложениями
#           </a>
#          </h3>
#         </div>
#        </div>
#        <!-- If we need pagination -->
#        <div class="swiper-pagination">
#        </div>
#        <div class="swiper-button-prev">
#        </div>
#        <div class="swiper-button-next">
#        </div>
#       </div>
#       <h6>
#        Самое сложное
#       </h6>
#      </section>
#      <div class="container">
#       <div class="line">
#        <a class="action-line-toggle" href="https://nplus1.ru/blog/2022/06/16/people-and-institutions-of-peters-reform">
#         <div class="heading">
#          <span>
#          </span>
#         </div>
#        </a>
#        <a class="container-link" href="https://nplus1.ru/blog/2022/06/16/people-and-institutions-of-peters-reform">
#         <div class="heading">
#          <span>
#           Книжная полка
#          </span>
#         </div>
#         <div class="link">
#          <span>
#           Дмитрий Серов «Люди и учреждения Петровской эпохи»
#          </span>
#         </div>
#        </a>
#        <a class="container-link" href="https://nplus1.ru/blog/2022/06/14/eye-of-the-albatross">
#         <div class="heading">
#          <span>
#           Книжная полка
#          </span>
#         </div>
#         <div class="link">
#          <span>
#           Карл Сафина «Глазами альбатроса»
#          </span>
#         </div>
#        </a>
#        <a class="container-link" href="https://nplus1.ru/blog/2022/06/09/le-theoreme-du-parapluie">
#         <div class="heading">
#          <span>
#           Книжная полка
#          </span>
#         </div>
#         <div class="link">
#          <span>
#           Микаэль Лонэ «Теорема зонтика, или Искусство правильно смотреть на мир через призму математики»
#          </span>
#         </div>
#        </a>
#        <a class="container-link" href="https://nplus1.ru/blog/2022/06/07/dig-for-science">
#         <div class="heading">
#          <span>
#           Эксперименты
#          </span>
#         </div>
#         <div class="link">
#          <span>
#           Кладмен — климатолог: как закапывать чайные пакетики, чтобы побыть своего рода ученым
#          </span>
#         </div>
#        </a>
#        <a class="container-link" href="https://nplus1.ru/blog/2022/06/07/breathing-lessons">
#         <div class="heading">
#          <span>
#           Книжная полка
#          </span>
#         </div>
#         <div class="link">
#          <span>
#           Мейлан Хан «Чудо дыхания. Как работают наши легкие и как поддержать их здоровье»
#          </span>
#         </div>
#        </a>
#        <a class="container-link" href="https://nplus1.ru/blog/2022/06/06/marat-spectrometric-analysis">
#         <div class="heading">
#          <span>
#           Эксперименты
#          </span>
#         </div>
#         <div class="link">
#          <span>
#           У меня в глазу спектрометр: инструкция по разложению света невооруженным взглядом
#          </span>
#         </div>
#        </a>
#        <a class="container-link" href="https://nplus1.ru/blog/2022/06/03/tastes-like-moon">
#         <div class="heading">
#          <span>
#           Хлеб и вино
#          </span>
#         </div>
#         <div class="link">
#          <span>
#           На вкус как Луна: зачем NASA кормило тараканов грунтом
#          </span>
#         </div>
#        </a>
#        <a class="container-link" href="https://nplus1.ru/blog/2022/06/03/from-earth-to-neptune-and-beyond">
#         <div class="heading">
#          <span>
#           Книжная полка
#          </span>
#         </div>
#         <div class="link">
#          <span>
#           Игорь Лисов «Разведчики внешних планет»
#          </span>
#         </div>
#        </a>
#        <a class="container-link" href="https://nplus1.ru/blog/2022/05/31/jellyfish-age-backwards">
#         <div class="heading">
#          <span>
#           Книжная полка
#          </span>
#         </div>
#         <div class="link">
#          <span>
#           Никлас Брендборг «Загадка нестареющей медузы»
#          </span>
#         </div>
#        </a>
#        <a class="container-link active" href="https://nplus1.ru/blog/2022/06/20/calling-bullshit">
#         <div class="heading">
#          <span>
#           Книжная полка
#          </span>
#         </div>
#         <div class="link">
#          <span>
#           Карл Бергстром, Джевин Уэст «Полный бред! Скептицизм в мире больших данных»
#          </span>
#         </div>
#        </a>
#       </div>
#      </div>
#      <script async="" src="https://cdn.onthe.io/io.js/QCyUUwp6IVuR">
#      </script>
#      <script>
#       window._io_config = window._io_config || {};
# window._io_config["0.2.0"] = window._io_config["0.2.0"] || [];
# window._io_config["0.2.0"].push({
#     page_url: document.location.toString(),
#     page_url_canonical: document.querySelector('link[rel="canonical"]').href,
#     page_title: document.querySelector('title').innerHTML,
#     page_type: "main",
#     page_language: "ru"
# });
#      </script>
#      <div class="ad ad-col border">
#      </div>
#      <!-- footer -->
#      <footer id="footer">
#       <div class="row" data-adaptive="1" data-middle-class="row-wrap" data-mobile-class="row-wrap" data-tablet-class="row-wrap">
#        <div class="col col-logo">
#         <a class="link-logo" href="/">
#          <img src="/i/logo-alt.png"/>
#         </a>
#        </div>
#        <div class="col col-footer-desc">
#         <nav class="nav-pages">
#          <ul>
#           <li>
#            <a href="/about">
#             О нас
#            </a>
#           </li>
#           <li>
#            <a href="https://nplus.pro" target="_blank">
#             N + Production
#            </a>
#           </li>
#           <li>
#            <a href="/adv">
#             Рекламодателям
#            </a>
#           </li>
#           <li>
#            <a href="/rules">
#             Наши материалы
#            </a>
#           </li>
#           <li>
#            <a href="/vacancy">
#             Вакансии
#            </a>
#           </li>
#           <li>
#            <a href="/blog/2022/04/01/samotek">
#             Авторам
#            </a>
#           </li>
#           <li>
#            <a href="/difficult">
#             Сложность
#            </a>
#           </li>
#          </ul>
#         </nav>
#         <div class="desc">
#          <p>
#           © 2022
#           <i>
#            N + 1
#           </i>
#           Интернет-издание   Свидетельство о регистрации СМИ Эл № ФС77-67614
#          </p>
#          <p>
#           Использование всех текстовых материалов без изменений в некоммерческих целях разрешается со ссылкой на
#           <i>
#            N + 1
#           </i>
#           .
#                         Все аудиовизуальные произведения являются собственностью своих авторов и правообладателей и используются
#                         только в образовательных и информационных целях. Если вы являетесь собственником того или иного произведения
#                         и не согласны с его размещением на нашем сайте, пожалуйста, напишите на kirill@nplus1.ru
#          </p>
#          <p>
#           Материалы, опубликованные в разделе «Блоги», отражают позиции их авторов, которые могут не совпадать с мнением редакции.
#          </p>
#          <p>
#           Сайт может содержать контент, не предназначенный для лиц младше 18 лет.
#          </p>
#          <p>
#           Связь с редакцией:
#           <a href="mailto:info@nplus1.ru">
#            info@nplus1.ru
#           </a>
#          </p>
#          <p>
#           <a class="pd" href="https://nplus1.ru/personal-data-policy">
#            Политика обработки персональных данных пользователей сайта
#           </a>
#          </p>
#          <p>
#          </p>
#          <p>
#          </p>
#         </div>
#        </div>
#        <div class="col col-1 pull-right">
#         <nav class="nav-social">
#          <ul>
#           <li>
#            <a href="https://t.me/nplusone">
#             <i class="fa fa-telegram">
#             </i>
#            </a>
#           </li>
#           <li>
#            <a href="http://vk.com/nplusone">
#             <i class="fa fa-vk">
#             </i>
#            </a>
#           </li>
#           <li>
#            <a href="https://twitter.com/nplusodin">
#             <i class="fa fa-twitter">
#             </i>
#            </a>
#           </li>
#           <li>
#            <a href="https://ok.ru/nplus1">
#             <i class="fa fa-odnoklassniki">
#             </i>
#            </a>
#           </li>
#           <li>
#            <a href="https://soundcloud.com/nplus_1">
#             <i class="fa fa-soundcloud">
#             </i>
#            </a>
#           </li>
#           <li>
#            <a href="/rss">
#             <i class="fa fa-rss">
#             </i>
#            </a>
#           </li>
#          </ul>
#         </nav>
#         <div class="partners">
#          <!-- Rating@Mail.ru counter -->
#          <script type="text/javascript">
#           var _tmr = window._tmr || (window._tmr = []);
# _tmr.push({id: "3084572", type: "pageView", start: (new Date()).getTime()});
# (function (d, w, id) {
#   if (d.getElementById(id)) return;
#   var ts = d.createElement("script"); ts.type = "text/javascript"; ts.async = true; ts.id = id;
#   ts.src = "https://top-fwz1.mail.ru/js/code.js";
#   var f = function () {var s = d.getElementsByTagName("script")[0]; s.parentNode.insertBefore(ts, s);};
#   if (w.opera == "[object Opera]") { d.addEventListener("DOMContentLoaded", f, false); } else { f(); }
# })(document, window, "topmailru-code");
#          </script>
#          <noscript>
#           <div>
#            <img alt="Top.Mail.Ru" src="https://top-fwz1.mail.ru/counter?id=3084572;js=na" style="border:0;position:absolute;left:-9999px;"/>
#           </div>
#          </noscript>
#          <!-- //Rating@Mail.ru counter -->
#         </div>
#        </div>
#       </div>
#      </footer>
#      <!-- / footer -->
#     </div>
#    </div>
#   </div>
#   <!-- Google Tag Manager -->
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-MNJC58');
#   </script>
#   <!-- End Google Tag Manager -->
#   <!-- Google Tag Manager (noscript) -->
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-MNJC58" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <!-- End Google Tag Manager (noscript) -->
#   <noscript>
#    <div>
#     <img alt="" src="//mc.yandex.ru/watch/29654565" style="position:absolute; left:-9999px;"/>
#    </div>
#   </noscript>
#   <script src="/js/lib/js.cookie.js">
#   </script>
#   <script src="/js/lib/jquery.swap.js">
#   </script>
#   <script src="/js/lib/swiper.jquery.min.js">
#   </script>
#   <script src="/js/lib/svg.js">
#   </script>
#   <script src="/js/lib/jquery.mobile-events.min.js">
#   </script>
#   <script src="/js/lib/social-likes.min.js">
#   </script>
#   <script src="/js/lib/jquery.sticky.js">
#   </script>
#   <script src="/js/tests/scopus/js/bundle.js">
#   </script>
#   <!--   project scripts -->
#   <script src="/js/main.min.js?v=1650440205">
#   </script>
#   <!-- / project scripts -->
#   <!-- Quantcast Tag -->
#   <script type="text/javascript">
#    var _qevents = _qevents || [];
#
# (function() {
# var elem = document.createElement('script');
# elem.src = (document.location.protocol == "https:" ? "https://secure" : "http://edge") + ".quantserve.com/quant.js";
# elem.async = true;
# elem.type = "text/javascript";
# var scpt = document.getElementsByTagName('script')[0];
# scpt.parentNode.insertBefore(elem, scpt);
# })();
#
# _qevents.push({
# qacct:"p-s3ftDEFzEW5x7"
# });
#   </script>
#   <noscript>
#    <div style="display:none;">
#     <img alt="Quantcast" border="0" height="1" src="//pixel.quantserve.com/pixel/p-s3ftDEFzEW5x7.gif" width="1"/>
#    </div>
#   </noscript>
#   <!-- End Quantcast tag -->
#  </body>
# </html>

# %% [markdown]
# В такой выдаче ориентироваться гораздо удобнее (но при желании, то же можно увидеть в браузере, на большом экране).

# %% [markdown]
# Чтобы сгрузить все новости с главной страницы сайта, нужно собрать все ссылки на страницы с этими новостями. Ссылки в html-файле всегда заключены в тэг `<a></a>` и имеют атрибут `href`. Посмотрим на кусочки кода, соответствующие всем ссылкам на главной странице сайта:

# %%
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# #
# /
# #
# #
# /rubric/astronomy
# /rubric/physics
# /rubric/biology
# /rubric/robots-drones
# /theme/bookshelf
# /theme/Courses
# /theme/coronavirus-history
# /theme/offline
# /
# #
# /rubric/astronomy
# /rubric/physics
# /rubric/biology
# /rubric/robots-drones
# #
# /theme/bookshelf
# /theme/Courses
# /theme/coronavirus-history
# /theme/offline
# https://nplus1.ru/blog/2022/06/16/people-and-institutions-of-peters-reform
# https://nplus1.ru/blog/2022/06/16/people-and-institutions-of-peters-reform
# https://nplus1.ru/blog/2022/06/14/eye-of-the-albatross
# https://nplus1.ru/blog/2022/06/09/le-theoreme-du-parapluie
# https://nplus1.ru/blog/2022/06/07/dig-for-science
# https://nplus1.ru/blog/2022/06/07/breathing-lessons
# https://nplus1.ru/blog/2022/06/06/marat-spectrometric-analysis
# https://nplus1.ru/blog/2022/06/03/tastes-like-moon
# https://nplus1.ru/blog/2022/06/03/from-earth-to-neptune-and-beyond
# https://nplus1.ru/blog/2022/05/31/jellyfish-age-backwards
# https://nplus1.ru/blog/2022/06/20/calling-bullshit
# /news/2022/06/20/phrynocephalus-mystaceus
# /news/2022/06/20/volumetric-avatar
# /news/2022/06/20/millet
# /news/2022/06/20/Spin-charge-separation
# /news/2022/06/20/fatherhood-relationships
# /news/2022/06/20/escherichia-coli
# /news/2022/06/20/phiale
# /material/2022/06/16/quantumalgorithms
# /rubric/physics
# /theme/alicebobcharlie
# /news/2022/06/19/drone-in-mars-winter
# /news/2022/06/18/moon-map
# /news/2022/06/18/perovskite-LCP
# /news/2022/06/18/hyades-and-sun
# /news/2022/06/18/shangdu
# /news/2022/06/18/drimolen
# /blog/2022/06/20/calling-bullshit
# /blog/2022/06/16/people-and-institutions-of-peters-reform
# /material/2022/06/15/trinityrex
# /rubric/paleontology
# /material/2022/06/03/deadly-food
# /rubric/medicine
# /theme/bread-and-wine
# /news/2022/06/17/polar-bears
# /news/2022/06/17/fullerene-monolayer
# /news/2022/06/17/giant-dwarf-crocodiles
# /news/2022/06/17/mars-debris
# /news/2022/06/17/vision-swimsion
# /news/2022/06/17/end-of-cern
# /blog/2022/06/17/sberautotech
# /blog/2022/06/14/eye-of-the-albatross
# /news/2022/06/06/are-you-rational
# /rubric/partners
# /material/2022/05/25/tequila-car-DIY
# /rubric/partners
# /theme/diy
# /news/2022/06/15/MicroBooNE-against-MiniBooNe
# /news/2022/06/16/MATTG
# /material/2022/06/16/quantumalgorithms
# /news/2022/06/17/isotopic-g-factor-difference
# /news/2022/06/20/Spin-charge-separation
# /news/2022/06/17/fullerene-monolayer
# /news/2022/06/16/1D-He4
# /news/2022/06/14/PN-formation
# /news/2022/06/14/hubble-bh-isolated
# /news/2022/06/15/complex-language
# https://nplus1.ru/blog/2022/06/16/people-and-institutions-of-peters-reform
# https://nplus1.ru/blog/2022/06/16/people-and-institutions-of-peters-reform
# https://nplus1.ru/blog/2022/06/14/eye-of-the-albatross
# https://nplus1.ru/blog/2022/06/09/le-theoreme-du-parapluie
# https://nplus1.ru/blog/2022/06/07/dig-for-science
# https://nplus1.ru/blog/2022/06/07/breathing-lessons
# https://nplus1.ru/blog/2022/06/06/marat-spectrometric-analysis
# https://nplus1.ru/blog/2022/06/03/tastes-like-moon
# https://nplus1.ru/blog/2022/06/03/from-earth-to-neptune-and-beyond
# https://nplus1.ru/blog/2022/05/31/jellyfish-age-backwards
# https://nplus1.ru/blog/2022/06/20/calling-bullshit
# /
# /about
# https://nplus.pro
# /adv
# /rules
# /vacancy
# /blog/2022/04/01/samotek
# /difficult
# mailto:info@nplus1.ru
# https://nplus1.ru/personal-data-policy
# https://t.me/nplusone
# http://vk.com/nplusone
# https://twitter.com/nplusodin
# https://ok.ru/nplus1
# https://soundcloud.com/nplus_1
# /rss

# %% [markdown]
# Ссылок много. Но нам нужны только новости – ссылки, которые начинаются со слова `/news`. Добавим условие: будем выбирать только те ссылки, в которых есть `/news`. Создадим пустой список `urls` и будем добавлять в него только ссылки, которые удовлетворяют этому условию.

# %%
urls = []

for link in soup.find_all('a'):
    if '/news' in link.get('href'):
        urls.append(link.get('href'))
urls
# Out:
# ['/news/2022/06/20/phrynocephalus-mystaceus',
#  '/news/2022/06/20/volumetric-avatar',
#  '/news/2022/06/20/millet',
#  '/news/2022/06/20/Spin-charge-separation',
#  '/news/2022/06/20/fatherhood-relationships',
#  '/news/2022/06/20/escherichia-coli',
#  '/news/2022/06/20/phiale',
#  '/news/2022/06/19/drone-in-mars-winter',
#  '/news/2022/06/18/moon-map',
#  '/news/2022/06/18/perovskite-LCP',
#  '/news/2022/06/18/hyades-and-sun',
#  '/news/2022/06/18/shangdu',
#  '/news/2022/06/18/drimolen',
#  '/news/2022/06/17/polar-bears',
#  '/news/2022/06/17/fullerene-monolayer',
#  '/news/2022/06/17/giant-dwarf-crocodiles',
#  '/news/2022/06/17/mars-debris',
#  '/news/2022/06/17/vision-swimsion',
#  '/news/2022/06/17/end-of-cern',
#  '/news/2022/06/06/are-you-rational',
#  '/news/2022/06/15/MicroBooNE-against-MiniBooNe',
#  '/news/2022/06/16/MATTG',
#  '/news/2022/06/17/isotopic-g-factor-difference',
#  '/news/2022/06/20/Spin-charge-separation',
#  '/news/2022/06/17/fullerene-monolayer',
#  '/news/2022/06/16/1D-He4',
#  '/news/2022/06/14/PN-formation',
#  '/news/2022/06/14/hubble-bh-isolated',
#  '/news/2022/06/15/complex-language']

# %% [markdown]
# Ссылки, которые у нас есть в списке `urls`, относительные: они неполные, начало ссылки (название сайта) отсутствует. Давайте превратим их в абсолютные ‒ склеим с ссылкой https://nplus1.ru.

# %%
full_urls = []

for u in urls:
    res = 'https://nplus1.ru' + u
    full_urls.append(res) 

full_urls
# Out:
# ['https://nplus1.ru/news/2022/06/20/phrynocephalus-mystaceus',
#  'https://nplus1.ru/news/2022/06/20/volumetric-avatar',
#  'https://nplus1.ru/news/2022/06/20/millet',
#  'https://nplus1.ru/news/2022/06/20/Spin-charge-separation',
#  'https://nplus1.ru/news/2022/06/20/fatherhood-relationships',
#  'https://nplus1.ru/news/2022/06/20/escherichia-coli',
#  'https://nplus1.ru/news/2022/06/20/phiale',
#  'https://nplus1.ru/news/2022/06/19/drone-in-mars-winter',
#  'https://nplus1.ru/news/2022/06/18/moon-map',
#  'https://nplus1.ru/news/2022/06/18/perovskite-LCP',
#  'https://nplus1.ru/news/2022/06/18/hyades-and-sun',
#  'https://nplus1.ru/news/2022/06/18/shangdu',
#  'https://nplus1.ru/news/2022/06/18/drimolen',
#  'https://nplus1.ru/news/2022/06/17/polar-bears',
#  'https://nplus1.ru/news/2022/06/17/fullerene-monolayer',
#  'https://nplus1.ru/news/2022/06/17/giant-dwarf-crocodiles',
#  'https://nplus1.ru/news/2022/06/17/mars-debris',
#  'https://nplus1.ru/news/2022/06/17/vision-swimsion',
#  'https://nplus1.ru/news/2022/06/17/end-of-cern',
#  'https://nplus1.ru/news/2022/06/06/are-you-rational',
#  'https://nplus1.ru/news/2022/06/15/MicroBooNE-against-MiniBooNe',
#  'https://nplus1.ru/news/2022/06/16/MATTG',
#  'https://nplus1.ru/news/2022/06/17/isotopic-g-factor-difference',
#  'https://nplus1.ru/news/2022/06/20/Spin-charge-separation',
#  'https://nplus1.ru/news/2022/06/17/fullerene-monolayer',
#  'https://nplus1.ru/news/2022/06/16/1D-He4',
#  'https://nplus1.ru/news/2022/06/14/PN-formation',
#  'https://nplus1.ru/news/2022/06/14/hubble-bh-isolated',
#  'https://nplus1.ru/news/2022/06/15/complex-language']

# %% [markdown]
# Теперь наша задача сводится к следующему: изучить одну страницу с новостью, научиться из нее вытаскивать текст и всю необходимую информацию, а потом применить весь набор действий к каждой ссылке из `full_urls` в цикле. Посмотрим на новость с индексом 1, у вас может быть другая, новости обновляются.

# %%
url0 = full_urls[1]

page0 = requests.get(url0)
soup0 = BeautifulSoup(page0.text, 'lxml')

# %%
url0
# Out:
# 'https://nplus1.ru/news/2022/06/20/volumetric-avatar'

# %% [markdown]
# В коде каждой страницы с новостью есть часть с мета-информацией: датой, именем автора и проч. Такая информация окружена тэгом `<meta></meta>`. Посмотрим:

# %%
soup0.find_all('meta')
# Out:
# [<meta charset="utf-8"/>,
#  <meta content="ie=edge" http-equiv="x-ua-compatible"/>,
#  <meta content="width=device-width, initial-scale=1" name="viewport"/>,
#  <meta content="yes" name="apple-mobile-web-app-capable"/>,
#  <meta content="black" name="apple-mobile-web-app-status-bar-style"/>,
#  <meta content="7991d7eb02d759f05b9050e111a7e3eb" name="wmail-verification"/>,
#  <meta content="2022-06-20" itemprop="datePublished"/>,
#  <meta content="Григорий Копиев" name="mediator_author"/>,
#  <meta content="Но пока метод требует несколько часов для обучения модели" name="description"/>,
#  <meta content="Григорий Копиев" name="author"/>,
#  <meta content="" name="copyright"/>,
#  <meta content="Meta научила смартфоны создавать реалистичную модель лица" property="og:title"/>,
#  <meta content="https://nplus1.ru/images/2022/06/20/c10ae4b76f52e9b41c12e6851033e715.gif" property="og:image"/>,
#  <meta content="https://nplus1.ru/news/2022/06/20/volumetric-avatar" property="og:url"/>,
#  <meta content="Но пока метод требует несколько часов для обучения модели" property="og:description"/>,
#  <meta content="summary_large_image" name="twitter:card"/>,
#  <meta content="@nplusodin" name="twitter:site"/>,
#  <meta content="Meta научила смартфоны создавать реалистичную модель лица" name="twitter:title"/>,
#  <meta content="Но пока метод требует несколько часов для обучения модели" name="twitter:description"/>,
#  <meta content="https://nplus1.ru/images/2022/06/20/c10ae4b76f52e9b41c12e6851033e715.gif" name="twitter:image"/>,
#  <meta content="8c90b02c84ac3b72" name="yandex-verification"/>,
#  <meta content="b419949322895fc9106e24ed01be58ac" name="pmail-verification"/>]

# %% [markdown]
# Из этого списка нам нужны части с именем автора, датой, заголовком и кратким описанием. Воспользуемся поиском по атрибуту `name`. Передадим функции `find_all()` в качестве аргумента словарь с названием и значением атрибута:

# %%
soup0.find_all('meta', {'name' : 'author'}) # например, автор
# Out:
# [<meta content="Григорий Копиев" name="author"/>]

# %% [markdown]
# Теперь выберем единственный элемент полученного списка (с индексом 0):

# %%
soup0.find_all('meta', {'name' : 'author'})[0]
# Out:
# <meta content="Григорий Копиев" name="author"/>

# %% [markdown]
# Нам нужно вытащить из этого объекта `content` – имя автора. Посмотрим на атрибуты:

# %%
soup0.find_all('meta', {'name' : 'author'})[0].attrs
# Out:
# {'name': 'author', 'content': 'Григорий Копиев'}

# %% [markdown]
# Как получить отсюда `content`? Очень просто, ведь это словарь! А доставать из словаря значение по ключу мы умеем.

# %%
author = soup0.find_all('meta', {'name' : 'author'})[0].attrs['content']
author
# Out:
# 'Григорий Копиев'

# %% [markdown]
# Аналогичным образом извлечем дату, заголовок и описание.

# %%
date = soup0.find_all('meta', {'itemprop' : 'datePublished'})[0].attrs['content']
title = soup0.find_all('meta', {'property' : 'og:title'})[0].attrs['content']
description = soup0.find_all('meta', {'name' : 'description'})[0].attrs['content']

# %% [markdown]
# Осталось вытащить рубрики и сложность текста. Если мы посмотрим на исходный код страницы, мы увидим, что нужная нам информация находится в тэгах `<p></p>`:

# %%
soup0.find_all('p')
# Out:
# [<p class="table">
#  <a data-rubric="it" href="/rubric/it">IT</a>
#  <a data-rubric="gadgets" href="/rubric/gadgets">Гаджеты</a>
#  </p>,
#  <p class="table">
#  <a href="/news/2022/06/20">
#  <time content="2022-06-20" data-unix="1655740061" itemprop="datePublished">
#  <span>18:47</span>
#  <span>20 Июнь 2022</span>
#  </time>
#  </a>
#  </p>,
#  <p class="table">
#  <a href="/difficult/3.6">
#  <span>Сложность</span>
#  <span class="difficult-value">3.6</span>
#  </a>
#  </p>,
#  <p class="title"></p>,
#  <p class="credits">Chen Cao et al. / SIGGRAPH 2022</p>,
#  <p>Разработчики из компании Meta создали алгоритм, позволяющий создавать качественную анимированную 3D-модель головы с помощью фронтальной камеры смартфона. <a href="https://drive.google.com/file/d/1i4NJKAggS82wqMamCJ1OHRGgViuyoY6R/view" rel="nofollow" target="_blank">Статья</a> будет представлена на конференции SIGGRAPH 2022.</p>,
#  <p>Немало крупных IT-компаний и лабораторий занимается разработкой технологий для создания реалистичных анимированных 3D-аватаров. К примеру, сама Meta еще в 2019 году <a href="https://www.wired.com/story/facebook-oculus-codec-avatars-vr/" rel="nofollow" target="_blank">показала</a> сферический стенд с более чем сотней камер и источников освещения, позволяющий снимать человека в центре с высоким разрешением и восстанавливать его 3D-модель. Во многом компания разрабатывает подобные технологии с прицелом на использование в виртуальной реальности. В частности, в апреле Meta <a href="https://www.youtube.com/watch?v=w52CziLgnAc" rel="nofollow" target="_blank">показала</a> работу нового алгоритма на прототипе VR-шлема с пятью камерами, направленными на разные части лица. Это позволило алгоритму в реальном времени воссоздавать реалистичную модель лица, которую можно показывать другим пользователям.<br/></p>,
#  <p>В новой работе инженеры из Meta Reality Labs под руководством Джейсона Сараги (Jason Saragih) использовали большой стенд с камерами для создания алгоритма, который после обучения позволяет создавать реалистичную модель головы с помощью обычного смартфона. Алгоритм состоит из двух основных частей: гиперсети, выучивающей универсальную модель головы и мимики, и персонализированной, которая создается на базе универсальной и выучивает модель для конкретного человека.</p>,
#  <p class="title">Схема работы метода</p>,
#  <p class="credits">Chen Cao et al. / SIGGRAPH 2022</p>,
#  <p>Для обучения универсальной сети инженеры использовали сферический стенд с 40 цветными камерами и 50 монохромными, установленными в радиусе 1,2 метра от центра сферы, где сидит человек во время съемки. Камеры снимали с разрешением 4096 на 2668 пикселя. Помимо камер в стенде есть 350 источников света, создающих равномерное освещение всей головы. Во время съемки человек в стенде должен был выполнить 65 мимических движений, посмотреть глазами в 25 разных направлений, прочитать 50 фонетически сбалансированных предложений и свободно подвигать головой или частями лица.</p>,
#  <p>В создании датасета участвовало 255 человек разного пола, расы и возраста. Всего во время съемки было сделано 3,1 миллиона кадров, которые затем использовали для обучения.</p>,
#  <p><iframe allowfullscreen="true" class="embed-responsive-item" frameborder="0" height="349" src="//www.youtube.com/embed/t7_TMD7v0Xs" width="620"></iframe><br/></p>,
#  <p>После создания универсальной модели с помощью мощного стенда персонализированную модель можно создавать при помощи обычной камеры. На
#  основе кадров с камеры алгоритм размечает на лице ключевые точки, затем
#  создает 3D-модель головы и текстуру, которую потом можно наложить на 3D-модель для создания относительно реалистичного аватара. На следующем на основе универсальной сети и этой модели с текстурой создается финальная персонализированная модель-аватар с высоким разрешением. Чтобы
#  она также хорошо повторяла мимику человека, его просят подвигать частями лица перед камерой.<br/></p>,
#  <p>Разработчики использовали для создания персонализированных моделей iPhone 12, чья фронтальная камера помимо RGB-слоя также выдает слой глубины. Несмотря на высокое качество генерации, авторы отмечают, что пока у алгоритма есть недостатки. В частности, после съемки персонализированная модель требует несколько часов для обучения, а также
#  она плохо работает с очками и необычными прическами.</p>,
#  <p>Создание реалистичной модели головы и лица можно использовать не только в виртуальной реальности, но и для видеосвязи. Так, разработчики из NVIDIA <a href="https://nplus1.ru/news/2020/10/06/nvidia-compression" target="_blank">предложили</a> заменять передачу видео на создание модели головы, передаваемой в сжатом виде, а инженеры из Google <a href="https://nplus1.ru/news/2021/12/06/google-light" target="_blank">создали</a> систему видеосвязи с объемным экраном, не требующим 3D-очков.<br/></p>,
#  <p><i>Григорий Копиев</i><br/></p>,
#  <p>Нашли опечатку? Выделите фрагмент и нажмите Ctrl+Enter.</p>,
#  <p class="subtitle">О чем сегодня ученые заставляют думать квантовые процессоры </p>,
#  <p>Коэффициент сложности</p>,
#  <p>Коэффициент сложности</p>,
#  <p>Коэффициент сложности</p>,
#  <p>Коэффициент сложности</p>,
#  <p>Коэффициент сложности</p>,
#  <p>Коэффициент сложности</p>,
#  <p>Коэффициент сложности</p>,
#  <p>Коэффициент сложности</p>,
#  <p>Коэффициент сложности</p>,
#  <p>Коэффициент сложности</p>,
#  <p>© 2022 <i>N + 1</i> Интернет-издание   Свидетельство о регистрации СМИ Эл № ФС77-67614</p>,
#  <p>Использование всех текстовых материалов без изменений в некоммерческих целях разрешается со ссылкой на <i>N + 1</i>.
#                          Все аудиовизуальные произведения являются собственностью своих авторов и правообладателей и используются
#                          только в образовательных и информационных целях. Если вы являетесь собственником того или иного произведения
#                          и не согласны с его размещением на нашем сайте, пожалуйста, напишите на kirill@nplus1.ru</p>,
#  <p>Материалы, опубликованные в разделе «Блоги», отражают позиции их авторов, которые могут не совпадать с мнением редакции.</p>,
#  <p>Сайт может содержать контент, не предназначенный для лиц младше 18 лет.</p>,
#  <p>Связь с редакцией: <a href="mailto:info@nplus1.ru">info@nplus1.ru</a></p>,
#  <p>
#  <a class="pd" href="https://nplus1.ru/personal-data-policy">Политика обработки персональных данных пользователей сайта</a>
#  </p>,
#  <p>
#  </p>,
#  <p>
#  </p>]

# %% [markdown]
# Выберем из полученного списка первый элемент и найдем в нем все тэги `<a>`:

# %%
soup0.find_all('p')[0].find_all('a')
# Out:
# [<a data-rubric="it" href="/rubric/it">IT</a>,
#  <a data-rubric="gadgets" href="/rubric/gadgets">Гаджеты</a>]

# %% [markdown]
# Получился список из одного элемента. Применим списковые включения – вытащим из каждого элемента (их могло бы быть больше) текст и поместим его в новый список `rubrics`.

# %%
soup0.find_all('p')[0].find_all('a')[0].text
# Out:
# 'IT'

# %%
rubrics = [r.text for r in soup0.find_all('p')[0].find_all('a')]
rubrics
# Out:
# ['IT', 'Гаджеты']

# %% [markdown]
# Осталась только сложность. Возьмем соответствующий кусок кода:

# %%
soup0.find_all('span', {'class' : 'difficult-value'})
# Out:
# [<span class="difficult-value">3.6</span>]

# %% [markdown]
# И выберем оттуда текст.

# %%
diff = soup0.find_all('span', {'class' : 'difficult-value'})[0].text
diff
# Out:
# '3.6'

# %% [markdown]
# Теперь перейдем к тексту самой новости. Как можно заметить, текст сохранен в абзацах `<p></p>`, причем безо всяких атрибутов. Сообщим Python, что нас интересуют куски с пустым атрибутом `class`:

# %%
text_list = soup0.find_all('p', {'class' : None})

# %%
text_list
# Out:
# [<p>Разработчики из компании Meta создали алгоритм, позволяющий создавать качественную анимированную 3D-модель головы с помощью фронтальной камеры смартфона. <a href="https://drive.google.com/file/d/1i4NJKAggS82wqMamCJ1OHRGgViuyoY6R/view" rel="nofollow" target="_blank">Статья</a> будет представлена на конференции SIGGRAPH 2022.</p>,
#  <p>Немало крупных IT-компаний и лабораторий занимается разработкой технологий для создания реалистичных анимированных 3D-аватаров. К примеру, сама Meta еще в 2019 году <a href="https://www.wired.com/story/facebook-oculus-codec-avatars-vr/" rel="nofollow" target="_blank">показала</a> сферический стенд с более чем сотней камер и источников освещения, позволяющий снимать человека в центре с высоким разрешением и восстанавливать его 3D-модель. Во многом компания разрабатывает подобные технологии с прицелом на использование в виртуальной реальности. В частности, в апреле Meta <a href="https://www.youtube.com/watch?v=w52CziLgnAc" rel="nofollow" target="_blank">показала</a> работу нового алгоритма на прототипе VR-шлема с пятью камерами, направленными на разные части лица. Это позволило алгоритму в реальном времени воссоздавать реалистичную модель лица, которую можно показывать другим пользователям.<br/></p>,
#  <p>В новой работе инженеры из Meta Reality Labs под руководством Джейсона Сараги (Jason Saragih) использовали большой стенд с камерами для создания алгоритма, который после обучения позволяет создавать реалистичную модель головы с помощью обычного смартфона. Алгоритм состоит из двух основных частей: гиперсети, выучивающей универсальную модель головы и мимики, и персонализированной, которая создается на базе универсальной и выучивает модель для конкретного человека.</p>,
#  <p>Для обучения универсальной сети инженеры использовали сферический стенд с 40 цветными камерами и 50 монохромными, установленными в радиусе 1,2 метра от центра сферы, где сидит человек во время съемки. Камеры снимали с разрешением 4096 на 2668 пикселя. Помимо камер в стенде есть 350 источников света, создающих равномерное освещение всей головы. Во время съемки человек в стенде должен был выполнить 65 мимических движений, посмотреть глазами в 25 разных направлений, прочитать 50 фонетически сбалансированных предложений и свободно подвигать головой или частями лица.</p>,
#  <p>В создании датасета участвовало 255 человек разного пола, расы и возраста. Всего во время съемки было сделано 3,1 миллиона кадров, которые затем использовали для обучения.</p>,
#  <p><iframe allowfullscreen="true" class="embed-responsive-item" frameborder="0" height="349" src="//www.youtube.com/embed/t7_TMD7v0Xs" width="620"></iframe><br/></p>,
#  <p>После создания универсальной модели с помощью мощного стенда персонализированную модель можно создавать при помощи обычной камеры. На
#  основе кадров с камеры алгоритм размечает на лице ключевые точки, затем
#  создает 3D-модель головы и текстуру, которую потом можно наложить на 3D-модель для создания относительно реалистичного аватара. На следующем на основе универсальной сети и этой модели с текстурой создается финальная персонализированная модель-аватар с высоким разрешением. Чтобы
#  она также хорошо повторяла мимику человека, его просят подвигать частями лица перед камерой.<br/></p>,
#  <p>Разработчики использовали для создания персонализированных моделей iPhone 12, чья фронтальная камера помимо RGB-слоя также выдает слой глубины. Несмотря на высокое качество генерации, авторы отмечают, что пока у алгоритма есть недостатки. В частности, после съемки персонализированная модель требует несколько часов для обучения, а также
#  она плохо работает с очками и необычными прическами.</p>,
#  <p>Создание реалистичной модели головы и лица можно использовать не только в виртуальной реальности, но и для видеосвязи. Так, разработчики из NVIDIA <a href="https://nplus1.ru/news/2020/10/06/nvidia-compression" target="_blank">предложили</a> заменять передачу видео на создание модели головы, передаваемой в сжатом виде, а инженеры из Google <a href="https://nplus1.ru/news/2021/12/06/google-light" target="_blank">создали</a> систему видеосвязи с объемным экраном, не требующим 3D-очков.<br/></p>,
#  <p><i>Григорий Копиев</i><br/></p>,
#  <p>Нашли опечатку? Выделите фрагмент и нажмите Ctrl+Enter.</p>,
#  <p>Коэффициент сложности</p>,
#  <p>Коэффициент сложности</p>,
#  <p>Коэффициент сложности</p>,
#  <p>Коэффициент сложности</p>,
#  <p>Коэффициент сложности</p>,
#  <p>Коэффициент сложности</p>,
#  <p>Коэффициент сложности</p>,
#  <p>Коэффициент сложности</p>,
#  <p>Коэффициент сложности</p>,
#  <p>Коэффициент сложности</p>,
#  <p>© 2022 <i>N + 1</i> Интернет-издание   Свидетельство о регистрации СМИ Эл № ФС77-67614</p>,
#  <p>Использование всех текстовых материалов без изменений в некоммерческих целях разрешается со ссылкой на <i>N + 1</i>.
#                          Все аудиовизуальные произведения являются собственностью своих авторов и правообладателей и используются
#                          только в образовательных и информационных целях. Если вы являетесь собственником того или иного произведения
#                          и не согласны с его размещением на нашем сайте, пожалуйста, напишите на kirill@nplus1.ru</p>,
#  <p>Материалы, опубликованные в разделе «Блоги», отражают позиции их авторов, которые могут не совпадать с мнением редакции.</p>,
#  <p>Сайт может содержать контент, не предназначенный для лиц младше 18 лет.</p>,
#  <p>Связь с редакцией: <a href="mailto:info@nplus1.ru">info@nplus1.ru</a></p>,
#  <p>
#  <a class="pd" href="https://nplus1.ru/personal-data-policy">Политика обработки персональных данных пользователей сайта</a>
#  </p>,
#  <p>
#  </p>,
#  <p>
#  </p>]

# %% [markdown]
# «Выцепим» все тексты (без тэгов) из полученного списка:

# %%
text = [t.text for t in text_list]

# %%
text
# Out:
# ['Разработчики из\xa0компании Meta создали алгоритм, позволяющий создавать качественную анимированную 3D-модель головы с\xa0помощью фронтальной камеры смартфона. Статья будет представлена на\xa0конференции SIGGRAPH 2022.',
#  'Немало крупных IT-компаний и\xa0лабораторий занимается разработкой технологий для создания реалистичных анимированных 3D-аватаров. К\xa0примеру, сама Meta еще в\xa02019 году показала сферический стенд с\xa0более чем сотней камер и\xa0источников освещения, позволяющий снимать человека в\xa0центре с\xa0высоким разрешением и\xa0восстанавливать его 3D-модель. Во\xa0многом компания разрабатывает подобные технологии с\xa0прицелом на\xa0использование в\xa0виртуальной реальности. В\xa0частности, в\xa0апреле Meta показала работу нового алгоритма на\xa0прототипе VR-шлема с\xa0пятью камерами, направленными на\xa0разные части лица. Это позволило алгоритму в\xa0реальном времени воссоздавать реалистичную модель лица, которую можно показывать другим пользователям.',
#  'В\xa0новой работе инженеры из\xa0Meta Reality Labs под руководством Джейсона Сараги (Jason Saragih) использовали большой стенд с\xa0камерами для создания алгоритма, который после обучения позволяет создавать реалистичную модель головы с\xa0помощью обычного смартфона. Алгоритм состоит из\xa0двух основных частей: гиперсети, выучивающей универсальную модель головы и\xa0мимики, и\xa0персонализированной, которая создается на\xa0базе универсальной и\xa0выучивает модель для конкретного человека.',
#  'Для обучения универсальной сети инженеры использовали сферический стенд с\xa040\xa0цветными камерами и\xa050\xa0монохромными, установленными в\xa0радиусе 1,2 метра от\xa0центра сферы, где сидит человек во\xa0время съемки. Камеры снимали с\xa0разрешением 4096\xa0на 2668\xa0пикселя. Помимо камер в\xa0стенде есть 350 источников света, создающих равномерное освещение всей головы. Во\xa0время съемки человек в\xa0стенде должен был выполнить 65\xa0мимических движений, посмотреть глазами в\xa025\xa0разных направлений, прочитать 50\xa0фонетически сбалансированных предложений и\xa0свободно подвигать головой или частями лица.',
#  'В\xa0создании датасета участвовало 255 человек разного пола, расы и\xa0возраста. Всего во\xa0время съемки было сделано 3,1 миллиона кадров, которые затем использовали для обучения.',
#  '',
#  'После создания универсальной модели с\xa0помощью мощного стенда персонализированную модель можно создавать при помощи обычной камеры. На\nоснове кадров с\xa0камеры алгоритм размечает на\xa0лице ключевые точки, затем\nсоздает 3D-модель головы и\xa0текстуру, которую потом можно наложить на\xa03D-модель для создания относительно реалистичного аватара. На\xa0следующем на\xa0основе универсальной сети и\xa0этой модели с\xa0текстурой создается финальная персонализированная модель-аватар с\xa0высоким разрешением. Чтобы\nона также хорошо повторяла мимику человека, его просят подвигать частями лица перед камерой.',
#  'Разработчики использовали для создания персонализированных моделей iPhone\xa012, чья фронтальная камера помимо RGB-слоя также выдает слой глубины. Несмотря на\xa0высокое качество генерации, авторы отмечают, что пока у\xa0алгоритма есть недостатки. В\xa0частности, после съемки персонализированная модель требует несколько часов для обучения, а\xa0также\nона плохо работает с\xa0очками и\xa0необычными прическами.',
#  'Создание реалистичной модели головы и\xa0лица можно использовать не\xa0только в\xa0виртуальной реальности, но\xa0и\xa0для видеосвязи. Так, разработчики из\xa0NVIDIA предложили заменять передачу видео на\xa0создание модели головы, передаваемой в\xa0сжатом виде, а\xa0инженеры из\xa0Google создали систему видеосвязи с\xa0объемным экраном, не\xa0требующим 3D-очков.',
#  'Григорий Копиев',
#  'Нашли опечатку? Выделите фрагмент и нажмите Ctrl+Enter.',
#  'Коэффициент сложности',
#  'Коэффициент сложности',
#  'Коэффициент сложности',
#  'Коэффициент сложности',
#  'Коэффициент сложности',
#  'Коэффициент сложности',
#  'Коэффициент сложности',
#  'Коэффициент сложности',
#  'Коэффициент сложности',
#  'Коэффициент сложности',
#  '© 2022 N\xa0+\xa01 Интернет-издание \xa0 Свидетельство о регистрации СМИ Эл № ФС77-67614',
#  'Использование всех текстовых материалов без изменений в некоммерческих целях разрешается со ссылкой на N\xa0+\xa01. \n                        Все аудиовизуальные произведения являются собственностью своих авторов и правообладателей и используются \n                        только в образовательных и информационных целях. Если вы являетесь собственником того или иного произведения \n                        и не согласны с его размещением на нашем сайте, пожалуйста, напишите на kirill@nplus1.ru',
#  'Материалы, опубликованные в разделе «Блоги», отражают позиции их авторов, которые могут не совпадать с мнением редакции.',
#  'Сайт может содержать контент, не предназначенный для лиц младше 18 лет.',
#  'Связь с редакцией: info@nplus1.ru',
#  '\nПолитика обработки персональных данных пользователей сайта\n',
#  '\n',
#  '\n']

# %% [markdown]
# Склеим все элементы списка `text` через пробел:

# %%
''.join(['1', '2', '3'])
# Out:
# '123'

# %%
final_text = ' '.join(text)
final_text
# Out:
# 'Разработчики из\xa0компании Meta создали алгоритм, позволяющий создавать качественную анимированную 3D-модель головы с\xa0помощью фронтальной камеры смартфона. Статья будет представлена на\xa0конференции SIGGRAPH 2022. Немало крупных IT-компаний и\xa0лабораторий занимается разработкой технологий для создания реалистичных анимированных 3D-аватаров. К\xa0примеру, сама Meta еще в\xa02019 году показала сферический стенд с\xa0более чем сотней камер и\xa0источников освещения, позволяющий снимать человека в\xa0центре с\xa0высоким разрешением и\xa0восстанавливать его 3D-модель. Во\xa0многом компания разрабатывает подобные технологии с\xa0прицелом на\xa0использование в\xa0виртуальной реальности. В\xa0частности, в\xa0апреле Meta показала работу нового алгоритма на\xa0прототипе VR-шлема с\xa0пятью камерами, направленными на\xa0разные части лица. Это позволило алгоритму в\xa0реальном времени воссоздавать реалистичную модель лица, которую можно показывать другим пользователям. В\xa0новой работе инженеры из\xa0Meta Reality Labs под руководством Джейсона Сараги (Jason Saragih) использовали большой стенд с\xa0камерами для создания алгоритма, который после обучения позволяет создавать реалистичную модель головы с\xa0помощью обычного смартфона. Алгоритм состоит из\xa0двух основных частей: гиперсети, выучивающей универсальную модель головы и\xa0мимики, и\xa0персонализированной, которая создается на\xa0базе универсальной и\xa0выучивает модель для конкретного человека. Для обучения универсальной сети инженеры использовали сферический стенд с\xa040\xa0цветными камерами и\xa050\xa0монохромными, установленными в\xa0радиусе 1,2 метра от\xa0центра сферы, где сидит человек во\xa0время съемки. Камеры снимали с\xa0разрешением 4096\xa0на 2668\xa0пикселя. Помимо камер в\xa0стенде есть 350 источников света, создающих равномерное освещение всей головы. Во\xa0время съемки человек в\xa0стенде должен был выполнить 65\xa0мимических движений, посмотреть глазами в\xa025\xa0разных направлений, прочитать 50\xa0фонетически сбалансированных предложений и\xa0свободно подвигать головой или частями лица. В\xa0создании датасета участвовало 255 человек разного пола, расы и\xa0возраста. Всего во\xa0время съемки было сделано 3,1 миллиона кадров, которые затем использовали для обучения.  После создания универсальной модели с\xa0помощью мощного стенда персонализированную модель можно создавать при помощи обычной камеры. На\nоснове кадров с\xa0камеры алгоритм размечает на\xa0лице ключевые точки, затем\nсоздает 3D-модель головы и\xa0текстуру, которую потом можно наложить на\xa03D-модель для создания относительно реалистичного аватара. На\xa0следующем на\xa0основе универсальной сети и\xa0этой модели с\xa0текстурой создается финальная персонализированная модель-аватар с\xa0высоким разрешением. Чтобы\nона также хорошо повторяла мимику человека, его просят подвигать частями лица перед камерой. Разработчики использовали для создания персонализированных моделей iPhone\xa012, чья фронтальная камера помимо RGB-слоя также выдает слой глубины. Несмотря на\xa0высокое качество генерации, авторы отмечают, что пока у\xa0алгоритма есть недостатки. В\xa0частности, после съемки персонализированная модель требует несколько часов для обучения, а\xa0также\nона плохо работает с\xa0очками и\xa0необычными прическами. Создание реалистичной модели головы и\xa0лица можно использовать не\xa0только в\xa0виртуальной реальности, но\xa0и\xa0для видеосвязи. Так, разработчики из\xa0NVIDIA предложили заменять передачу видео на\xa0создание модели головы, передаваемой в\xa0сжатом виде, а\xa0инженеры из\xa0Google создали систему видеосвязи с\xa0объемным экраном, не\xa0требующим 3D-очков. Григорий Копиев Нашли опечатку? Выделите фрагмент и нажмите Ctrl+Enter. Коэффициент сложности Коэффициент сложности Коэффициент сложности Коэффициент сложности Коэффициент сложности Коэффициент сложности Коэффициент сложности Коэффициент сложности Коэффициент сложности Коэффициент сложности © 2022 N\xa0+\xa01 Интернет-издание \xa0  ...

# %% [markdown]
# Все здорово, только мешают отступы-переходы на новую строку `\n`. Заменим их на пробелы с помощью метода `.replace`:

# %%
final_text = final_text.replace('\n', ' ')

# %%
final_text
# Out:
# 'Разработчики из\xa0компании Meta создали алгоритм, позволяющий создавать качественную анимированную 3D-модель головы с\xa0помощью фронтальной камеры смартфона. Статья будет представлена на\xa0конференции SIGGRAPH 2022. Немало крупных IT-компаний и\xa0лабораторий занимается разработкой технологий для создания реалистичных анимированных 3D-аватаров. К\xa0примеру, сама Meta еще в\xa02019 году показала сферический стенд с\xa0более чем сотней камер и\xa0источников освещения, позволяющий снимать человека в\xa0центре с\xa0высоким разрешением и\xa0восстанавливать его 3D-модель. Во\xa0многом компания разрабатывает подобные технологии с\xa0прицелом на\xa0использование в\xa0виртуальной реальности. В\xa0частности, в\xa0апреле Meta показала работу нового алгоритма на\xa0прототипе VR-шлема с\xa0пятью камерами, направленными на\xa0разные части лица. Это позволило алгоритму в\xa0реальном времени воссоздавать реалистичную модель лица, которую можно показывать другим пользователям. В\xa0новой работе инженеры из\xa0Meta Reality Labs под руководством Джейсона Сараги (Jason Saragih) использовали большой стенд с\xa0камерами для создания алгоритма, который после обучения позволяет создавать реалистичную модель головы с\xa0помощью обычного смартфона. Алгоритм состоит из\xa0двух основных частей: гиперсети, выучивающей универсальную модель головы и\xa0мимики, и\xa0персонализированной, которая создается на\xa0базе универсальной и\xa0выучивает модель для конкретного человека. Для обучения универсальной сети инженеры использовали сферический стенд с\xa040\xa0цветными камерами и\xa050\xa0монохромными, установленными в\xa0радиусе 1,2 метра от\xa0центра сферы, где сидит человек во\xa0время съемки. Камеры снимали с\xa0разрешением 4096\xa0на 2668\xa0пикселя. Помимо камер в\xa0стенде есть 350 источников света, создающих равномерное освещение всей головы. Во\xa0время съемки человек в\xa0стенде должен был выполнить 65\xa0мимических движений, посмотреть глазами в\xa025\xa0разных направлений, прочитать 50\xa0фонетически сбалансированных предложений и\xa0свободно подвигать головой или частями лица. В\xa0создании датасета участвовало 255 человек разного пола, расы и\xa0возраста. Всего во\xa0время съемки было сделано 3,1 миллиона кадров, которые затем использовали для обучения.  После создания универсальной модели с\xa0помощью мощного стенда персонализированную модель можно создавать при помощи обычной камеры. На основе кадров с\xa0камеры алгоритм размечает на\xa0лице ключевые точки, затем создает 3D-модель головы и\xa0текстуру, которую потом можно наложить на\xa03D-модель для создания относительно реалистичного аватара. На\xa0следующем на\xa0основе универсальной сети и\xa0этой модели с\xa0текстурой создается финальная персонализированная модель-аватар с\xa0высоким разрешением. Чтобы она также хорошо повторяла мимику человека, его просят подвигать частями лица перед камерой. Разработчики использовали для создания персонализированных моделей iPhone\xa012, чья фронтальная камера помимо RGB-слоя также выдает слой глубины. Несмотря на\xa0высокое качество генерации, авторы отмечают, что пока у\xa0алгоритма есть недостатки. В\xa0частности, после съемки персонализированная модель требует несколько часов для обучения, а\xa0также она плохо работает с\xa0очками и\xa0необычными прическами. Создание реалистичной модели головы и\xa0лица можно использовать не\xa0только в\xa0виртуальной реальности, но\xa0и\xa0для видеосвязи. Так, разработчики из\xa0NVIDIA предложили заменять передачу видео на\xa0создание модели головы, передаваемой в\xa0сжатом виде, а\xa0инженеры из\xa0Google создали систему видеосвязи с\xa0объемным экраном, не\xa0требующим 3D-очков. Григорий Копиев Нашли опечатку? Выделите фрагмент и нажмите Ctrl+Enter. Коэффициент сложности Коэффициент сложности Коэффициент сложности Коэффициент сложности Коэффициент сложности Коэффициент сложности Коэффициент сложности Коэффициент сложности Коэффициент сложности Коэффициент сложности © 2022 N\xa0+\xa01 Интернет-издание \xa0 Свид ...

# %% [markdown]
# Не прошло и двух пар, как мы разобрались со всем :) Теперь осталось совсем чуть-чуть. Написать готовую функцию для всех проделанных нами действий и применить ее в цикле для всех ссылок в списке `full_urls`. Напишем! Аргументом функции будет ссылка на новость, а возвращать она будет текст новости и всю необходимую информацию (дата, автор, сложность и проч.). Скопируем все строки кода выше.

# %%
def GetNews(url0):
    """
    Returns a tuple with url0, date, author, description, title, final_text, rubrics, diff.
    Parameters:
    
    url0 is a link to the news (string)
    """
    page0 = requests.get(url0)
    soup0 = BeautifulSoup(page0.text, 'lxml')
    author = soup0.find_all('meta', {'name' : 'author'})[0].attrs['content']
    date = soup0.find_all('meta', {'itemprop' : 'datePublished'})[0].attrs['content']
    title = soup0.find_all('meta', {'property' : 'og:title'})[0].attrs['content']
    description = soup0.find_all('meta', {'name' : 'description'})[0].attrs['content']
    rubrics = [r.text for r in soup0.find_all('p')[0].find_all('a')]
    diff = soup0.find_all('span', {'class' : 'difficult-value'})[0].text
    text_list = soup0.find_all('p', {'class' : None})
    text = [t.text for t in text_list]
    final_text = ' '.join(text)
    final_text = final_text.replace('\n', ' ')
    
    return url0, date, author, description, title, final_text, rubrics, diff

# %% [markdown]
# Уфф. Осталось применить ее в цикле. Но давайте не будем спешить: импортируем функцию `sleep` для задержки, чтобы на каждой итерации цикла, прежде чем перейти к следующей новости, Python ждал несколько секунд. Во-первых, это нужно, чтобы сайт «не понял», чтобы мы его грабим, да еще автоматически. Во-вторых, с небольшой задержкой всегда есть гарантия, что страница прогрузится (сейчас это пока не очень важно, но особенно актуально будет, когда будем обсуждать встраивание в браузер с Selenium). Приступим.

# %%
from time import sleep

# %%
news = [] # это будет список из кортежей, в которых будут храниться данные по каждой новости

for link in full_urls:
    res = GetNews(link)
    news.append(res)
    sleep(3) # задержка в 3 секунды

# %% [markdown]
# Так теперь выглядит первый элемент списка:

# %%
len(news)
# Out:
# 29

# %%
news[0]
# Out:
# ('https://nplus1.ru/news/2022/06/20/phrynocephalus-mystaceus',
#  '2022-06-20',
#  'Сергей Коленов',
#  'Единственным назначением этих кожных складок оказалась защита от хищников.',
#  'Круглоголовки отказались раскрывать «уши» перед сородичами',
#  'Пустынные ящерицы ушастые круглоголовки в\xa0случае опасности пугают хищников, раскрывая ярко-красные складки в\xa0уголках рта. Зоологи предположили, что эти украшения могут использоваться и\xa0во\xa0время социальных взаимодействий, например, чтобы привлечь самку или прогнать соперника. Однако эксперименты не\xa0подтвердили данную идею: в\xa0присутствии сородичей ящерицы отказывались демонстрировать кожные складки. Результаты исследования опубликованы в\xa0статье для журнала Biological Journal of\xa0the Linnean Society. Ушастые круглоголовки (Phrynocephalus mystaceus)\xa0— типичные обитатели пустынь и\xa0полупустынь от\xa0Южной России до\xa0Ирана и\xa0Китая. На\xa0первый взгляд эти скромно окрашенные ящерицы из\xa0семейства агам (Agamidae) кажутся совершенно непримечательными. Однако в\xa0случае опасности они преображаются. раздувают тело, расставляют ноги и\xa0широко раскрывает пасть. При этом ярко-красные кожные складки в\xa0углах их\xa0рта наливаются кровью и\xa0становятся похожими на\xa0уши (отсюда и\xa0происходит название вида). Такая демонстрация должна убедить хищника, что круглоголовка намного крупнее и\xa0опаснее, чем на\xa0самом деле. А\xa0если угроза не\xa0сработает, ящерица попытается укусить врага. Команда зоологов, которую возглавил Инь\xa0Ци (Yin\xa0Qi) из\xa0Биологического института в\xa0Чэнду, предположила, что кожные складки круглоголовок могут иметь двойное назначение и\xa0использоваться не\xa0только для защиты от\xa0хищников, но\xa0и\xa0для привлечения партнеров или отпугивания конкурентов. Чтобы проверить эту гипотезу, исследователи отправились в\xa0пустыню Тукай, поймали несколько ящериц и\xa0провели с\xa0ними ряд экспериментов в\xa0открытых вольерах. Они помещали в\xa0один вольер по\xa0две особи одного пола или по\xa0две особи разных полов, после чего фиксировали их\xa0поведение. В\xa0дополнительных экспериментах круглоголовок держали на\xa0привязи в\xa0естественной среде обитания и\xa0сводили их\xa0с\xa0сородичами того\xa0же или противоположного пола. Исследователи обнаружили, что при встрече с\xa0сородичами, независимо от\xa0их\xa0пола, круглоголовки не\xa0раскрывают кожные складки в\xa0уголках рта. Вместо этого ящерицы подавали друг другу сигналы с\xa0помощью движений хвоста. Подобный способ общения круглоголовок уже давно известен герпетологам. Таким образом, авторам удалось стимулировать у\xa0ящериц социальное поведение, однако оно не\xa0включало демонстраций с\xa0использованием кожных складок. Инь Ци\xa0с\xa0коллегами также оценили размеры и\xa0расцветку «ушей» у\xa0ящериц разного пола. Если\xa0бы самцы использовали эти складки для привлечения партнерш, то\xa0они были\xa0бы у\xa0них крупнее и\xa0ярче. Однако анализ не\xa0выявил полового диморфизма в\xa0размере кожных складок. Кроме того, хроматический контраст рта и\xa0«ушей» оказался примерно одинаковым у\xa0самцов и\xa0самок. Лишь яркостный контраст складок, но\xa0не\xa0рта, достигает у\xa0самцов более высоких значений, чем у\xa0самок. Дополнительный анализ показал, что «уши» самцов лучше заметны для птиц, чем «уши» самок. Для других частей тела или для зрительной системы змей эта закономерность не\xa0подтверждается. Авторы допускают, что поведение самцов каким-то образом делает их\xa0особенно уязвимыми для хищных птиц, поэтому им\xa0нужны более яркие предупреждающие сигналы. На\xa0следующем этапе исследователи проверяли реакцию круглоголовок на\xa0хищников.\xa038\xa0особей помещали в\xa0открытый вольер и\xa0демонстрировали им\xa0изображение обыкновенной пустельги (Falco tinnunculus) в\xa0полете или T-образную палку. Если ящерицы раскрывали кожные складки в\xa0знак угрозы в\xa0течение двух минут, испытание прекращали. В\xa0противном случае подопытных особей осторожно прижимали к\xa0песку изображением птицы или палки. Если и\xa0это не\xa0вызывало реакции, ящериц слегка щелкали по\xa0морде пальцем десять раз. В\xa0немного модифицированном виде эксперимент повторили с\xa0особями, которых держали на\xa0привязи в\xa0естественной среде обитания. Один ...
#  ['Зоология'],
#  '2.7')

# %% [markdown]
# Импортируем `pandas` и создадим датафрейм из списка кортежей:

# %%
import pandas as pd

# %%
df = pd.DataFrame(news)

# %%
df.head(2)
# Out:
#                                                    0           1  \
# 0  https://nplus1.ru/news/2022/06/20/phrynocephal...  2022-06-20
# 1  https://nplus1.ru/news/2022/06/20/volumetric-a...  2022-06-20
#
#                  2                                                  3  \
# 0   Сергей Коленов  Единственным назначением этих кожных складок о...
# 1  Григорий Копиев  Но пока метод требует несколько часов для обуч...
#
#                                                    4  \
# 0  Круглоголовки отказались раскрывать «уши» пере...
# 1  Meta научила смартфоны создавать реалистичную ...
#
#                                                    5              6    7
# 0  Пустынные ящерицы ушастые круглоголовки в случ...     [Зоология]  2.7
# 1  Разработчики из компании Meta создали алгоритм...  [IT, Гаджеты]  3.6

# %% [markdown]
# Переименуем столбцы в базе.

# %%
df.columns = ['link', 'date', 'author', 'desc', 'title', 'text', 'rubric', 'diffc']

# %%
df.head(2)
# Out:
#                                                 link        date  \
# 0  https://nplus1.ru/news/2022/06/20/phrynocephal...  2022-06-20
# 1  https://nplus1.ru/news/2022/06/20/volumetric-a...  2022-06-20
#
#             author                                               desc  \
# 0   Сергей Коленов  Единственным назначением этих кожных складок о...
# 1  Григорий Копиев  Но пока метод требует несколько часов для обуч...
#
#                                                title  \
# 0  Круглоголовки отказались раскрывать «уши» пере...
# 1  Meta научила смартфоны создавать реалистичную ...
#
#                                                 text         rubric diffc
# 0  Пустынные ящерицы ушастые круглоголовки в случ...     [Зоология]   2.7
# 1  Разработчики из компании Meta создали алгоритм...  [IT, Гаджеты]   3.6

# %%
df.dtypes #object ~ string
# Out:
# link      object
# date      object
# author    object
# desc      object
# title     object
# text      object
# rubric    object
# diffc     object
# dtype: object

# %% [markdown]
# Теперь внесем изменения: сделаем столбец `diffc` числовым – типа *float*.

# %%
df['diffc'] = df['diffc'].apply(float)

# %%
df.dtypes
# Out:
# link       object
# date       object
# author     object
# desc       object
# title      object
# text       object
# rubric     object
# diffc     float64
# dtype: object

# %% [markdown]
# Теперь сложность представлена в базе как количественный показатель, и описывать ее можно соответствующим образом:

# %%
df.diffc.describe()
# Out:
# count    29.000000
# mean      4.368966
# std       2.311787
# min       1.100000
# 25%       2.600000
# 50%       3.900000
# 75%       6.500000
# max       9.400000
# Name: diffc, dtype: float64

# %% [markdown]
# Теперь столбец со сложностью точно числовой. Можем даже построить для него гистограмму.

# %%
df.diffc.plot.hist();

# %% [markdown]
# Объединим рубрики в *text* в одну строку через запятую:

# %%
df['rubric'] = [','.join(r) for r in df.rubric]

# %% [markdown]
# Давайте почистим текст новостей – уберем оттуда текст, не относящийся к новостям. Найдем лишнее:

# %%
df.text[0]
# Out:
# 'Пустынные ящерицы ушастые круглоголовки в\xa0случае опасности пугают хищников, раскрывая ярко-красные складки в\xa0уголках рта. Зоологи предположили, что эти украшения могут использоваться и\xa0во\xa0время социальных взаимодействий, например, чтобы привлечь самку или прогнать соперника. Однако эксперименты не\xa0подтвердили данную идею: в\xa0присутствии сородичей ящерицы отказывались демонстрировать кожные складки. Результаты исследования опубликованы в\xa0статье для журнала Biological Journal of\xa0the Linnean Society. Ушастые круглоголовки (Phrynocephalus mystaceus)\xa0— типичные обитатели пустынь и\xa0полупустынь от\xa0Южной России до\xa0Ирана и\xa0Китая. На\xa0первый взгляд эти скромно окрашенные ящерицы из\xa0семейства агам (Agamidae) кажутся совершенно непримечательными. Однако в\xa0случае опасности они преображаются. раздувают тело, расставляют ноги и\xa0широко раскрывает пасть. При этом ярко-красные кожные складки в\xa0углах их\xa0рта наливаются кровью и\xa0становятся похожими на\xa0уши (отсюда и\xa0происходит название вида). Такая демонстрация должна убедить хищника, что круглоголовка намного крупнее и\xa0опаснее, чем на\xa0самом деле. А\xa0если угроза не\xa0сработает, ящерица попытается укусить врага. Команда зоологов, которую возглавил Инь\xa0Ци (Yin\xa0Qi) из\xa0Биологического института в\xa0Чэнду, предположила, что кожные складки круглоголовок могут иметь двойное назначение и\xa0использоваться не\xa0только для защиты от\xa0хищников, но\xa0и\xa0для привлечения партнеров или отпугивания конкурентов. Чтобы проверить эту гипотезу, исследователи отправились в\xa0пустыню Тукай, поймали несколько ящериц и\xa0провели с\xa0ними ряд экспериментов в\xa0открытых вольерах. Они помещали в\xa0один вольер по\xa0две особи одного пола или по\xa0две особи разных полов, после чего фиксировали их\xa0поведение. В\xa0дополнительных экспериментах круглоголовок держали на\xa0привязи в\xa0естественной среде обитания и\xa0сводили их\xa0с\xa0сородичами того\xa0же или противоположного пола. Исследователи обнаружили, что при встрече с\xa0сородичами, независимо от\xa0их\xa0пола, круглоголовки не\xa0раскрывают кожные складки в\xa0уголках рта. Вместо этого ящерицы подавали друг другу сигналы с\xa0помощью движений хвоста. Подобный способ общения круглоголовок уже давно известен герпетологам. Таким образом, авторам удалось стимулировать у\xa0ящериц социальное поведение, однако оно не\xa0включало демонстраций с\xa0использованием кожных складок. Инь Ци\xa0с\xa0коллегами также оценили размеры и\xa0расцветку «ушей» у\xa0ящериц разного пола. Если\xa0бы самцы использовали эти складки для привлечения партнерш, то\xa0они были\xa0бы у\xa0них крупнее и\xa0ярче. Однако анализ не\xa0выявил полового диморфизма в\xa0размере кожных складок. Кроме того, хроматический контраст рта и\xa0«ушей» оказался примерно одинаковым у\xa0самцов и\xa0самок. Лишь яркостный контраст складок, но\xa0не\xa0рта, достигает у\xa0самцов более высоких значений, чем у\xa0самок. Дополнительный анализ показал, что «уши» самцов лучше заметны для птиц, чем «уши» самок. Для других частей тела или для зрительной системы змей эта закономерность не\xa0подтверждается. Авторы допускают, что поведение самцов каким-то образом делает их\xa0особенно уязвимыми для хищных птиц, поэтому им\xa0нужны более яркие предупреждающие сигналы. На\xa0следующем этапе исследователи проверяли реакцию круглоголовок на\xa0хищников.\xa038\xa0особей помещали в\xa0открытый вольер и\xa0демонстрировали им\xa0изображение обыкновенной пустельги (Falco tinnunculus) в\xa0полете или T-образную палку. Если ящерицы раскрывали кожные складки в\xa0знак угрозы в\xa0течение двух минут, испытание прекращали. В\xa0противном случае подопытных особей осторожно прижимали к\xa0песку изображением птицы или палки. Если и\xa0это не\xa0вызывало реакции, ящериц слегка щелкали по\xa0морде пальцем десять раз. В\xa0немного модифицированном виде эксперимент повторили с\xa0особями, которых держали на\xa0привязи в\xa0естественной среде обитания. Один  ...

# %% [markdown]
# Лишний текст находится после фразы 'Нашли опечатку?'. Так давайте будем разбивать строки по этой фразе с помощью метода `.split()` и брать все, что до нее (элемент с индексом 0).

# %%
df['clean_text'] = [t.split('Нашли опечатку?')[0] for t in df.text]

# %% [markdown]
# Осталось только заменить непонятные символы `\xa0` на пробелы:

# %%
df['clean_text'] = [t.replace("\xa0", " ") for t in df.clean_text]

# %%
df.clean_text[0]
# Out:
# 'Пустынные ящерицы ушастые круглоголовки в случае опасности пугают хищников, раскрывая ярко-красные складки в уголках рта. Зоологи предположили, что эти украшения могут использоваться и во время социальных взаимодействий, например, чтобы привлечь самку или прогнать соперника. Однако эксперименты не подтвердили данную идею: в присутствии сородичей ящерицы отказывались демонстрировать кожные складки. Результаты исследования опубликованы в статье для журнала Biological Journal of the Linnean Society. Ушастые круглоголовки (Phrynocephalus mystaceus) — типичные обитатели пустынь и полупустынь от Южной России до Ирана и Китая. На первый взгляд эти скромно окрашенные ящерицы из семейства агам (Agamidae) кажутся совершенно непримечательными. Однако в случае опасности они преображаются. раздувают тело, расставляют ноги и широко раскрывает пасть. При этом ярко-красные кожные складки в углах их рта наливаются кровью и становятся похожими на уши (отсюда и происходит название вида). Такая демонстрация должна убедить хищника, что круглоголовка намного крупнее и опаснее, чем на самом деле. А если угроза не сработает, ящерица попытается укусить врага. Команда зоологов, которую возглавил Инь Ци (Yin Qi) из Биологического института в Чэнду, предположила, что кожные складки круглоголовок могут иметь двойное назначение и использоваться не только для защиты от хищников, но и для привлечения партнеров или отпугивания конкурентов. Чтобы проверить эту гипотезу, исследователи отправились в пустыню Тукай, поймали несколько ящериц и провели с ними ряд экспериментов в открытых вольерах. Они помещали в один вольер по две особи одного пола или по две особи разных полов, после чего фиксировали их поведение. В дополнительных экспериментах круглоголовок держали на привязи в естественной среде обитания и сводили их с сородичами того же или противоположного пола. Исследователи обнаружили, что при встрече с сородичами, независимо от их пола, круглоголовки не раскрывают кожные складки в уголках рта. Вместо этого ящерицы подавали друг другу сигналы с помощью движений хвоста. Подобный способ общения круглоголовок уже давно известен герпетологам. Таким образом, авторам удалось стимулировать у ящериц социальное поведение, однако оно не включало демонстраций с использованием кожных складок. Инь Ци с коллегами также оценили размеры и расцветку «ушей» у ящериц разного пола. Если бы самцы использовали эти складки для привлечения партнерш, то они были бы у них крупнее и ярче. Однако анализ не выявил полового диморфизма в размере кожных складок. Кроме того, хроматический контраст рта и «ушей» оказался примерно одинаковым у самцов и самок. Лишь яркостный контраст складок, но не рта, достигает у самцов более высоких значений, чем у самок. Дополнительный анализ показал, что «уши» самцов лучше заметны для птиц, чем «уши» самок. Для других частей тела или для зрительной системы змей эта закономерность не подтверждается. Авторы допускают, что поведение самцов каким-то образом делает их особенно уязвимыми для хищных птиц, поэтому им нужны более яркие предупреждающие сигналы. На следующем этапе исследователи проверяли реакцию круглоголовок на хищников. 38 особей помещали в открытый вольер и демонстрировали им изображение обыкновенной пустельги (Falco tinnunculus) в полете или T-образную палку. Если ящерицы раскрывали кожные складки в знак угрозы в течение двух минут, испытание прекращали. В противном случае подопытных особей осторожно прижимали к песку изображением птицы или палки. Если и это не вызывало реакции, ящериц слегка щелкали по морде пальцем десять раз. В немного модифицированном виде эксперимент повторили с особями, которых держали на привязи в естественной среде обитания. Один из исследователей приближался к ним с изображением птицы в руке, а затем ловил. После поимки ящериц десять раз щелкали пальцем по морде. Кроме того, авторы проверили, как отреагируют на присутствие врага 25 диких круглоголовок. Исследователь приближался к ящерицам, ловил с помощью лассо и проверя ...

# %% [markdown]
# Всё! Сохраняем датафрейм в файл. Для разнообразия сохраним в Excel:

# %%
df.head()
# Out:
#                                                 link        date  \
# 0  https://nplus1.ru/news/2022/06/20/phrynocephal...  2022-06-20
# 1  https://nplus1.ru/news/2022/06/20/volumetric-a...  2022-06-20
# 2           https://nplus1.ru/news/2022/06/20/millet  2022-06-20
# 3  https://nplus1.ru/news/2022/06/20/Spin-charge-...  2022-06-20
# 4  https://nplus1.ru/news/2022/06/20/fatherhood-r...  2022-06-20
#
#               author                                               desc  \
# 0     Сергей Коленов  Единственным назначением этих кожных складок о...
# 1    Григорий Копиев  Но пока метод требует несколько часов для обуч...
# 2    Михаил Подрезов       Его использовали в качестве заупокойной пищи
# 3     Марат Хамадеев  Для этого они облучали холодные атомы лития, в...
# 4  Анастасия Ляшенко  Наличие прошлых отношений также повысило шансы...
#
#                                                title  \
# 0  Круглоголовки отказались раскрывать «уши» пере...
# 1  Meta научила смартфоны создавать реалистичную ...
# 2  В сосуде из тюркского погребения VII века обна...
# 3  Физики подтвердили спин-зарядовое разделение в...
# 4  Желание стать отцом привлекло женщин для долго...
#
#                                                 text                 rubric  \
# 0  Пустынные ящерицы ушастые круглоголовки в случ...               Зоология
# 1  Разработчики из компании Meta создали алгоритм...             IT,Гаджеты
# 2  Археологи исследовали заполнение керамического...  Археология,Археология
# 3  Физики из Китая и США смогли независимо измери...                 Физика
# 4  Австралийские исследователи выявили, что успех...             Психология
#
#    diffc                                         clean_text
# 0    2.7  Пустынные ящерицы ушастые круглоголовки в случ...
# 1    3.6  Разработчики из компании Meta создали алгоритм...
# 2    3.2  Археологи исследовали заполнение керамического...
# 3    7.1  Физики из Китая и США смогли независимо измери...
# 4    2.1  Австралийские исследователи выявили, что успех...

# %%
df.to_excel('nplus-news.xlsx', index=False)
